# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv
from collections import OrderedDict
from update_dataframe import *
from matplotlib import cbook
import seaborn as sns
import math

# %%
# #creating a new dataframe

# columns = [['Date','Total_Sent','Sent_On_Date','Proceed_In_24_Hr','Total_Positive','New_Positive']]
# test_report = pd.DataFrame(columns=columns)
# test_report.to_csv('data/Analysis_Test_Results.csv')

# %%
test_report = pd.read_csv('data/Analysis_Test_Results.csv')
test_report
# Out:
#     Unnamed: 0        Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  \
# 0            0  04/08/2020      858960         24745             20087
# 1            1  05/08/2020      884056         25096             25096
# 2            2  06/08/2020      908355         24299             25205
# 3            3  07/08/2020      936651         28296             27608
# 4            4  08/08/2020      963632         26981             27714
# 5            5  09/08/2020      984208         20576             22745
# 6            6  10/08/2020     1000988         16780             20583
# 7            7  11/08/2020     1027433         26445             21625
# 8            8  12/08/2020     1056360         28927             28644
# 9            9  13/08/2020     1087722         31362             31270
# 10          10  14/08/2020     1120935         33213             31738
# 11          11  15/08/2020     1154365         33430             32108
# 12          12  16/08/2020     1182727         28362             30123
# 13          13  17/08/2020     1205759         23032             26150
# 14          14  18/08/2020     1240076         34317             29265
# 15          15  19/08/2020     1276358         36282             36291
# 16          16  20/08/2020     1312992         36634             37010
# 17          17  21/08/2020     1349071         36079             35825
# 18          18  22/08/2020     1386775         37704             37027
# 19          19  23/08/2020      142258         37583             36353
# 20          20  24/08/2020     1446380         23822             26186
# 21          21  25/08/2020     1484907         38527             34344
# 22          22  26/08/2020     1525792         40885             40352
# 23          23  27/08/2020     1525792             0             37873
# 24          24  28/08/2020     1608013         82221             41860
# 25          25  29/08/2020     1643633         35620             34988
#
#     Total_Positive  New_Positive
# 0            27956          1083
# 1            29151          1195
# 2            30449          1298
# 3            31700          1251
# 4            33120          1420
# 5            34331          1211
# 6            35515          1184
# 7            36932          1417
# 8            38144          1212
# 9            39708          1564
# 10           41277          1569
# 11           42885          1608
# 12           44415          1530
# 13           46140          1725
# 14           47898          1758
# 15           50231          2333
# 16           52199          1968
# 17           54182          1983
# 18           56354          2172
# 19           58262          1908
# 20           59504          1242
# 21           61879          2375
# 22           64355          2476
# 23           66761          2406
# 24           69304          2543
# 25           71701          2397

# %%
file_path = 'data/Analysis_Test_Results.csv'
#update_file(test_report,file_path)

# %%
#check if there is unwanterd columns ?
print(test_report.columns)
inp = input("is there any unwanted coumns ? (y/n)")
if inp == 'y':
    column_name =  input("Enter column name :")
    del test_report[column_name]
    test_report.to_csv(file_path, index = True)
# Out:
# Index(['Unnamed: 0', 'Date', 'Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr',
#        'Total_Positive', 'New_Positive'],
#       dtype='object')
# is there any unwanted coumns ? (y/n)y
# Enter column name :Unnamed: 0

# %%
update_file(test_report,file_path)
# Out:
# Do you have to update the data  : (y/n)y
# <class 'str'>
# hi
#  Options !!
# 	Add Column : c
# 	Add row values : r
# Enter your optionr
# -------------------
# Adding row values
# -------------------
# Enter Date 30/08/2020
# Enter Total_Sent 1669779
# Enter Sent_On_Date 26146
# Enter Proceed_In_24_Hr 27908
# Enter Total_Positive 73855
# Enter New_Positive 2154
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# Do you want to save these changes (y/n): y
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# do you want to add more : (y/n)y
#  Options !!
# 	Add Column : c
# 	Add row values : r
# Enter your optionr
# -------------------
# Adding row values
# -------------------
# Enter Date 31/08/2020
# Enter Total_Sent 1685203
# Enter Sent_On_Date 15424
# Enter Proceed_In_24_Hr 18027
# Enter Total_Positive 75385
# Enter New_Positive 1530
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# Do you want to save these changes (y/n): y
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# do you want to add more : (y/n)n
# Final :
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# Do you want to overwrite csv file : (y/n) y
# Successully saved data

# %%
#test_report = pd.read_csv('data/Analysis_Test_Results.csv')
test_report
# Out:
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530

# %% [markdown]
# ## Trying to train the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
features = test_report[['Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr', 'Total_Positive']]
label = test_report[['New_Positive']]

# %%
features
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 0       858960         24745             20087           27956
# 1       884056         25096             25096           29151
# 2       908355         24299             25205           30449
# 3       936651         28296             27608           31700
# 4       963632         26981             27714           33120
# 5       984208         20576             22745           34331
# 6      1000988         16780             20583           35515
# 7      1027433         26445             21625           36932
# 8      1056360         28927             28644           38144
# 9      1087722         31362             31270           39708
# 10     1120935         33213             31738           41277
# 11     1154365         33430             32108           42885
# 12     1182727         28362             30123           44415
# 13     1205759         23032             26150           46140
# 14     1240076         34317             29265           47898
# 15     1276358         36282             36291           50231
# 16     1312992         36634             37010           52199
# 17     1349071         36079             35825           54182
# 18     1386775         37704             37027           56354
# 19      142258         37583             36353           58262
# 20     1446380         23822             26186           59504
# 21     1484907         38527             34344           61879
# 22     1525792         40885             40352           64355
# 23     1525792             0             37873           66761
# 24     1608013         82221             41860           69304
# 25     1643633         35620             34988           71701
# 26     1669779         26146             27908           73855
# 27     1685203         15424             18027           75385

# %%
label
# Out:
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530

# %%
# Create a correlation matrix
corr_metrics = features.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col2 {
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col0 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col1 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col0 {
#             background-color:  #2d8abd;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col2 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total_Sent</th>        <th class="col_heading level0 col1" >Sent_On_Date</th>        <th class="col_heading level0 col2" >Proceed_In_24_Hr</th>        <th class="col_heading level0 col3" >Total_Positive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7level0_row0" class="row_heading level0 row0" >Total_Sent</th>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col1" class="data row0 col1" >0.136820</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col2" class="data row0 col2" >0.266981</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row0_col3" class="data row0 col3" >0.694240</td>
#             </tr>
#             <tr>
#                         <th id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7level0_row1" class="row_heading level0 row1" >Sent_On_Date</th>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col0" class="data row1 col0" >0.136820</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col2" class="data row1 col2" >0.587636</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row1_col3" class="data row1 col3" >0.244835</td>
#             </tr>
#             <tr>
#                         <th id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7level0_row2" class="row_heading level0 row2" >Proceed_In_24_Hr</th>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col0" class="data row2 col0" >0.266981</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col1" class="data row2 col1" >0.587636</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row2_col3" class="data row2 col3" >0.494202</td>
#             </tr>
#             <tr>
#                         <th id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7level0_row3" class="row_heading level0 row3" >Total_Positive</th>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col0" class="data row3 col0" >0.694240</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col1" class="data row3 col1" >0.244835</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col2" class="data row3 col2" >0.494202</td>
#                         <td id="T_2efee2ec_ec24_11ea_be4e_507b9d5f0fd7row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# features = test_report[['Sent_On_Date', 'Proceed_In_24_Hr']]
# label = test_report[['New_Positive']]

# %%
type(features)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size = 0.3,random_state=42)

# %%
x_train
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 13     1205759         23032             26150           46140
# 15     1276358         36282             36291           50231
# 1       884056         25096             25096           29151
# 4       963632         26981             27714           33120
# 5       984208         20576             22745           34331
# 2       908355         24299             25205           30449
# 16     1312992         36634             37010           52199
# 23     1525792             0             37873           66761
# 3       936651         28296             27608           31700
# 26     1669779         26146             27908           73855
# 24     1608013         82221             41860           69304
# 18     1386775         37704             37027           56354
# 27     1685203         15424             18027           75385
# 20     1446380         23822             26186           59504
# 7      1027433         26445             21625           36932
# 10     1120935         33213             31738           41277
# 14     1240076         34317             29265           47898
# 19      142258         37583             36353           58262
# 6      1000988         16780             20583           35515

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted = model.predict(x_test)

# %%
predicted
# Out:
# array([[1681.3540738 ],
#        [2282.12659467],
#        [1538.85648075],
#        [2120.19996839],
#        [1002.0000536 ],
#        [1695.98195636],
#        [2086.96229381],
#        [2431.38138173],
#        [1763.9250543 ]])

# %%
y_test
# Out:
#     New_Positive
# 9           1564
# 25          2397
# 8           1212
# 21          2375
# 0           1083
# 12          1530
# 17          1983
# 22          2476
# 11          1608

# %%
model.score(x_test,y_test)
# Out:
# 0.877446725746371

# %%
model.score(x_train,y_train)
# Out:
# 0.8651328192020126

# %%
error = metrics.mean_squared_error(y_test,predicted)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predicted)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  173.18862432100164
# r2 score :  0.877446725746371

# %%
test = [1685203,15424,18027,75385]

# %%
test_predicted = model.predict(np.array(test).reshape(1,-1))

# %%
actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1551

# %% [markdown]
# ## Using MLPRegressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
model_mlp = MLPRegressor(solver='sgd')

# %%
model_mlp.fit(x_train,y_train)
# Out:
# C:\Users\Shoukkiya_Ashraf\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='sgd',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)

# %%
predict_mlp = model_mlp.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_mlp)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_mlp)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  1.1204434543564874e+21
# r2 score :  -5.1293942582530917e+36

# %%
test_predicted = model_mlp.predict(np.array(test).reshape(1,-1))

# %%
test_predicted
# Out:
# array([1.12044345e+21])

# %% [markdown]
# ## Using  DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor()

# %%
model_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
predict_tree = model_tree.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_tree)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_tree)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  163.30577998888398
# r2 score :  0.8910344271669216

# %%
model_tree.score(x_test,y_test)
# Out:
# 0.8910344271669216

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knn = KNeighborsRegressor()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
predict_knn = model.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_knn)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_knn)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  173.18862432100164
# r2 score :  0.877446725746371

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.7101109807214807

# %%
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1975

# %%
print('prediction by Linearregression')
test_predicted = model.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))

print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# prediction by Linearregression
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1551
# prediction by KNNregressor
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1975

# %% [markdown]
# # Trying with xgboost

# %%
import xgboost as xgb

# %%
model_xgb = xgb.XGBRFRegressor()

# %%
model_xgb.fit(x_train,y_train)
# Out:
# [13:11:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRFRegressor(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                colsample_bytree=1, gamma=0, learning_rate=1, max_delta_step=0,
#                max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#                n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=0.8, verbosity=1)

# %%
predict_xgb = model_xgb.predict(x_test)

# %%
predict_xgb
# Out:
# array([1603.4891, 1603.4891, 1603.4891, 1603.4891, 1580.5844, 1603.4891,
#        1603.4891, 1603.4891, 1603.4891], dtype=float32)

# %%
y_test
# Out:
#     New_Positive
# 9           1564
# 25          2397
# 8           1212
# 21          2375
# 0           1083
# 12          1530
# 17          1983
# 22          2476
# 11          1608

# %%
error = metrics.mean_squared_error(y_test,predict_xgb)
print('mean squared error : ',error)
r2_Score = metrics.r2_score(y_test,predict_xgb)
print("r2 score : ",r2_Score)
# Out:
# mean squared error :  282002.9479847766
# r2 score :  -0.15223176044397224

# %%
#current best 
print('prediction by Linearregression')
test_predicted = model.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))

print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# prediction by Linearregression
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1551
# prediction by KNNregressor
# new test positives on ['31/08/2020']
# actual :     1530
# predicted :  1975

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1,len(x_train.columns.values),sharey=True,constrained_layout=True,figsize=(30,15))

for i,e in enumerate(x_train.columns):
  model.fit(x_train[e].values[:,np.newaxis], y_train.values)
  axes[i].set_title("Best fit line")
  axes[i].set_xlabel(str(e))
  axes[i].set_ylabel('new positive')
  axes[i].scatter(x_train[e].values[:,np.newaxis], y_train,color='g')
  axes[i].plot(x_train[e].values[:,np.newaxis],model.predict(x_train[e].values[:,np.newaxis]),color='k')

# %%
total_snt = int(test_report['Total_Sent'].tail(1).values)
total_snt
# Out:
# 1685203

# %%
#calculating total processed
Proceed_In_24_Hr = test_report['Proceed_In_24_Hr'].values

# %%
total_processed = 0
for i in Proceed_In_24_Hr:
    total_processed = total_processed + i
print('total processed until {0} :'.format(test_report['Date'].tail(1).values),total_processed)
unprocessed = total_snt-total_processed
print('Unprocessed cases : ',unprocessed)
# Out:
# total processed until ['31/08/2020'] : 844005
# Unprocessed cases :  841198

# %%
perentage_processed = (total_processed/total_snt)*100
perentage_unprocessed = (unprocessed/total_snt)*100
percentage = [perentage_processed,perentage_unprocessed]
percentage
# Out:
# [50.08328373495657, 49.91671626504344]

# %%
fig_pie , ax_pie = plt.subplots()

#setting the theme
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['axes.labelcolor'] = '#909090'
plt.rcParams['font.size'] = 12

#setting label names and percentages
ax_pie.set_title('\nVisualizing test reports processed v/s unprocessed\n\n',fontsize='xx-large')
labels = ['Test_Processed','Test_Unprocessed']
explode=(0.1,0)
ax_pie.pie(percentage,explode=explode,labels=labels, autopct='%1.0f%%', 
       shadow=False,colors = ['#5ADAE0','#367DB5'], startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax_pie.axis('equal')
ax_pie.legend(frameon=False, bbox_to_anchor=(1.5,0.8))
