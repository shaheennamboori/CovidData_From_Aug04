# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import csv
from collections import OrderedDict
from update_dataframe import *
from matplotlib import cbook
import seaborn as sns
import math

# %%
# #creating a new dataframe

# columns = [['Date','Total_Sent','Sent_On_Date','Proceed_In_24_Hr','Total_Positive','New_Positive']]
# test_report = pd.DataFrame(columns=columns)
# test_report.to_csv('data/Analysis_Test_Results.csv')

# %%
test_report = pd.read_csv('data/Analysis_Test_Results.csv')
test_report
# Out:
#     Unnamed: 0        Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  \
# 0            0  04/08/2020      858960         24745             20087
# 1            1  05/08/2020      884056         25096             25096
# 2            2  06/08/2020      908355         24299             25205
# 3            3  07/08/2020      936651         28296             27608
# 4            4  08/08/2020      963632         26981             27714
# 5            5  09/08/2020      984208         20576             22745
# 6            6  10/08/2020     1000988         16780             20583
# 7            7  11/08/2020     1027433         26445             21625
# 8            8  12/08/2020     1056360         28927             28644
# 9            9  13/08/2020     1087722         31362             31270
# 10          10  14/08/2020     1120935         33213             31738
# 11          11  15/08/2020     1154365         33430             32108
# 12          12  16/08/2020     1182727         28362             30123
# 13          13  17/08/2020     1205759         23032             26150
# 14          14  18/08/2020     1240076         34317             29265
# 15          15  19/08/2020     1276358         36282             36291
# 16          16  20/08/2020     1312992         36634             37010
# 17          17  21/08/2020     1349071         36079             35825
# 18          18  22/08/2020     1386775         37704             37027
# 19          19  23/08/2020      142258         37583             36353
# 20          20  24/08/2020     1446380         23822             26186
# 21          21  25/08/2020     1484907         38527             34344
# 22          22  26/08/2020     1525792         40885             40352
# 23          23  27/08/2020     1525792             0             37873
# 24          24  28/08/2020     1608013         82221             41860
# 25          25  29/08/2020     1643633         35620             34988
# 26          26  30/08/2020     1669779         26146             27908
# 27          27  31/08/2020     1685203         15424             18027
# 28          28  01/09/2020     1697042         11839             14137
#
#     Total_Positive  New_Positive
# 0            27956          1083
# 1            29151          1195
# 2            30449          1298
# 3            31700          1251
# 4            33120          1420
# 5            34331          1211
# 6            35515          1184
# 7            36932          1417
# 8            38144          1212
# 9            39708          1564
# 10           41277          1569
# 11           42885          1608
# 12           44415          1530
# 13           46140          1725
# 14           47898          1758
# 15           50231          2333
# 16           52199          1968
# 17           54182          1983
# 18           56354          2172
# 19           58262          1908
# 20           59504          1242
# 21           61879          2375
# 22           64355          2476
# 23           66761          2406
# 24           69304          2543
# 25           71701          2397
# 26           73855          2154
# 27           75385          1530
# 28           76525          1140

# %%
file_path = 'data/Analysis_Test_Results.csv'
#update_file(test_report,file_path)

# %%
#check if there is unwanterd columns ?
print(test_report.columns)
inp = input("is there any unwanted coumns ? (y/n)")
if inp == 'y':
    check = input('Is column name is Unnamed: 0 (y/n)')
    if check == 'y':
        del test_report['Unnamed: 0']
        print('deleted')
    else :
        column_name =  input("Enter column name :")
        del test_report[column_name]
        print('deleted')
test_report.to_csv(file_path, index = True)
# Out:
# Index(['Unnamed: 0', 'Date', 'Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr',
#        'Total_Positive', 'New_Positive'],
#       dtype='object')
# is there any unwanted coumns ? (y/n)y
# Is column name is Unnamed: 0 (y/n)y
# deleted

# %%
update_file(test_report,file_path)
# Out:
# Do you have to update the data  : (y/n)y
# <class 'str'>
# hi
#  Options !!
# 	Add Column : c
# 	Add row values : r
# Enter your optionr
# -------------------
# Adding row values
# -------------------
# Enter Date 02/09/2020
# Enter Total_Sent 1724658
# Enter Sent_On_Date 27616
# Enter Proceed_In_24_Hr 23850
# Enter Total_Positive 78072
# Enter New_Positive 1547
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# Do you want to save these changes (y/n): y
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# do you want to add more : (y/n)y
#  Options !!
# 	Add Column : c
# 	Add row values : r
# Enter your optionr
# -------------------
# Adding row values
# -------------------
# Enter Date 03/09/2020
# Enter Total_Sent 1755568
# Enter Sent_On_Date 30910
# Enter Proceed_In_24_Hr 30342
# Enter Total_Positive 79625
# Enter New_Positive 1553
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
# 30  03/09/2020     1755568         30910             30342           79625
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# 30          1553
# Do you want to save these changes (y/n): y
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
# 30  03/09/2020     1755568         30910             30342           79625
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# 30          1553
# do you want to add more : (y/n)n
# Final :
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
# 30  03/09/2020     1755568         30910             30342           79625
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# 30          1553
# Do you want to overwrite csv file : (y/n) y
# Successully saved data

# %%
#test_report = pd.read_csv('data/Analysis_Test_Results.csv')
test_report
# Out:
#           Date  Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive  \
# 0   04/08/2020      858960         24745             20087           27956
# 1   05/08/2020      884056         25096             25096           29151
# 2   06/08/2020      908355         24299             25205           30449
# 3   07/08/2020      936651         28296             27608           31700
# 4   08/08/2020      963632         26981             27714           33120
# 5   09/08/2020      984208         20576             22745           34331
# 6   10/08/2020     1000988         16780             20583           35515
# 7   11/08/2020     1027433         26445             21625           36932
# 8   12/08/2020     1056360         28927             28644           38144
# 9   13/08/2020     1087722         31362             31270           39708
# 10  14/08/2020     1120935         33213             31738           41277
# 11  15/08/2020     1154365         33430             32108           42885
# 12  16/08/2020     1182727         28362             30123           44415
# 13  17/08/2020     1205759         23032             26150           46140
# 14  18/08/2020     1240076         34317             29265           47898
# 15  19/08/2020     1276358         36282             36291           50231
# 16  20/08/2020     1312992         36634             37010           52199
# 17  21/08/2020     1349071         36079             35825           54182
# 18  22/08/2020     1386775         37704             37027           56354
# 19  23/08/2020      142258         37583             36353           58262
# 20  24/08/2020     1446380         23822             26186           59504
# 21  25/08/2020     1484907         38527             34344           61879
# 22  26/08/2020     1525792         40885             40352           64355
# 23  27/08/2020     1525792             0             37873           66761
# 24  28/08/2020     1608013         82221             41860           69304
# 25  29/08/2020     1643633         35620             34988           71701
# 26  30/08/2020     1669779         26146             27908           73855
# 27  31/08/2020     1685203         15424             18027           75385
# 28  01/09/2020     1697042         11839             14137           76525
# 29  02/09/2020     1724658         27616             23850           78072
# 30  03/09/2020     1755568         30910             30342           79625
#
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# 30          1553

# %% [markdown]
# ## Trying to train the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
features = test_report[['Total_Sent', 'Sent_On_Date', 'Proceed_In_24_Hr', 'Total_Positive']]
label = test_report[['New_Positive']]

# %%
features
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 0       858960         24745             20087           27956
# 1       884056         25096             25096           29151
# 2       908355         24299             25205           30449
# 3       936651         28296             27608           31700
# 4       963632         26981             27714           33120
# 5       984208         20576             22745           34331
# 6      1000988         16780             20583           35515
# 7      1027433         26445             21625           36932
# 8      1056360         28927             28644           38144
# 9      1087722         31362             31270           39708
# 10     1120935         33213             31738           41277
# 11     1154365         33430             32108           42885
# 12     1182727         28362             30123           44415
# 13     1205759         23032             26150           46140
# 14     1240076         34317             29265           47898
# 15     1276358         36282             36291           50231
# 16     1312992         36634             37010           52199
# 17     1349071         36079             35825           54182
# 18     1386775         37704             37027           56354
# 19      142258         37583             36353           58262
# 20     1446380         23822             26186           59504
# 21     1484907         38527             34344           61879
# 22     1525792         40885             40352           64355
# 23     1525792             0             37873           66761
# 24     1608013         82221             41860           69304
# 25     1643633         35620             34988           71701
# 26     1669779         26146             27908           73855
# 27     1685203         15424             18027           75385
# 28     1697042         11839             14137           76525
# 29     1724658         27616             23850           78072
# 30     1755568         30910             30342           79625

# %%
label
# Out:
#     New_Positive
# 0           1083
# 1           1195
# 2           1298
# 3           1251
# 4           1420
# 5           1211
# 6           1184
# 7           1417
# 8           1212
# 9           1564
# 10          1569
# 11          1608
# 12          1530
# 13          1725
# 14          1758
# 15          2333
# 16          1968
# 17          1983
# 18          2172
# 19          1908
# 20          1242
# 21          2375
# 22          2476
# 23          2406
# 24          2543
# 25          2397
# 26          2154
# 27          1530
# 28          1140
# 29          1547
# 30          1553

# %%
# Create a correlation matrix
corr_metrics = features.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col2 {
#             background-color:  #4897c4;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col1 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col3 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col0 {
#             background-color:  #056faf;
#             color:  #f1f1f1;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total_Sent</th>        <th class="col_heading level0 col1" >Sent_On_Date</th>        <th class="col_heading level0 col2" >Proceed_In_24_Hr</th>        <th class="col_heading level0 col3" >Total_Positive</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7level0_row0" class="row_heading level0 row0" >Total_Sent</th>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col1" class="data row0 col1" >0.050259</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col2" class="data row0 col2" >0.074929</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row0_col3" class="data row0 col3" >0.763880</td>
#             </tr>
#             <tr>
#                         <th id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7level0_row1" class="row_heading level0 row1" >Sent_On_Date</th>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col0" class="data row1 col0" >0.050259</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col2" class="data row1 col2" >0.619966</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row1_col3" class="data row1 col3" >0.120223</td>
#             </tr>
#             <tr>
#                         <th id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7level0_row2" class="row_heading level0 row2" >Proceed_In_24_Hr</th>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col0" class="data row2 col0" >0.074929</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col1" class="data row2 col1" >0.619966</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row2_col3" class="data row2 col3" >0.210858</td>
#             </tr>
#             <tr>
#                         <th id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7level0_row3" class="row_heading level0 row3" >Total_Positive</th>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col0" class="data row3 col0" >0.763880</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col1" class="data row3 col1" >0.120223</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col2" class="data row3 col2" >0.210858</td>
#                         <td id="T_b2fe0dd8_ee78_11ea_acb3_507b9d5f0fd7row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# features = test_report[['Sent_On_Date', 'Proceed_In_24_Hr']]
# label = test_report[['New_Positive']]

# %%
type(features)
# Out:
# pandas.core.frame.DataFrame

# %%
x_train,x_test,y_train,y_test = train_test_split(features,label,test_size = 0.3,random_state=42)

# %%
x_train
# Out:
#     Total_Sent  Sent_On_Date  Proceed_In_24_Hr  Total_Positive
# 4       963632         26981             27714           33120
# 16     1312992         36634             37010           52199
# 5       984208         20576             22745           34331
# 13     1205759         23032             26150           46140
# 11     1154365         33430             32108           42885
# 22     1525792         40885             40352           64355
# 1       884056         25096             25096           29151
# 2       908355         24299             25205           30449
# 25     1643633         35620             34988           71701
# 3       936651         28296             27608           31700
# 21     1484907         38527             34344           61879
# 26     1669779         26146             27908           73855
# 18     1386775         37704             37027           56354
# 30     1755568         30910             30342           79625
# 20     1446380         23822             26186           59504
# 7      1027433         26445             21625           36932
# 10     1120935         33213             31738           41277
# 14     1240076         34317             29265           47898
# 28     1697042         11839             14137           76525
# 19      142258         37583             36353           58262
# 6      1000988         16780             20583           35515

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted = model.predict(x_test)

# %%
predicted
# Out:
# array([[1346.77882727],
#        [2024.29962648],
#        [1584.27532377],
#        [2046.84383176],
#        [1539.17821322],
#        [1678.40491122],
#        [1765.79534097],
#        [3202.31623803],
#        [1639.69952427],
#        [1100.22383602]])

# %%
y_test
# Out:
#     New_Positive
# 27          1530
# 15          2333
# 23          2406
# 17          1983
# 8           1212
# 9           1564
# 29          1547
# 24          2543
# 12          1530
# 0           1083

# %%
model.score(x_test,y_test)
# Out:
# 0.39565663456419564

# %%
model.score(x_train,y_train)
# Out:
# 0.7919453967270166

# %%
error = metrics.mean_squared_error(y_test,predicted)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predicted)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  377.25421311752007
# r2 score :  0.39565663456419564

# %%
testa = test_report.iloc[:,1:5].tail(1).values
test = []
for i in testa:
    for j in i :
        print(type(j))
        test.append(j)
print(test)
print(test_report.iloc[:,5].tail(1).values)
# Out:
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# <class 'numpy.int64'>
# [1755568, 30910, 30342, 79625]
# [1553]

# %%
test_predicted = model.predict(np.array(test).reshape(1,-1))

# %%
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['03/09/2020']
# actual :     [1553]
# predicted :  2037

# %% [markdown]
# ## Using MLPRegressor

# %%
from sklearn.neural_network import MLPRegressor

# %%
model_mlp = MLPRegressor(solver='sgd')

# %%
model_mlp.fit(x_train,y_train)
# Out:
# C:\Users\Shoukkiya_Ashraf\miniconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=200,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=None, shuffle=True, solver='sgd',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)

# %%
predict_mlp = model_mlp.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_mlp)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_mlp)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  1.4372035573556229e+20
# r2 score :  -8.771060941399412e+34

# %%
test_predicted = model_mlp.predict(np.array(test).reshape(1,-1))

# %%
test_predicted
# Out:
# array([1.43720356e+20])

# %% [markdown]
# ## Using  DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor()

# %%
model_tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
predict_tree = model_tree.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_tree)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_tree)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  322.19869645918806
# r2 score :  0.5591781431646816

# %%
model_tree.score(x_test,y_test)
# Out:
# 0.5591781431646816

# %%
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
# Out:
# new test positives on ['03/09/2020']
# actual :     [1553]
# predicted :  1553

# %%
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
print(test_predicted_tree)
# Out:
# [1553.]

# %%
check = [1724658,27616,23850,78072]
print(model_tree.predict(np.array(check).reshape(1,-1)))
actual_check = 1547
# Out:
# [1417.]

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knn = KNeighborsRegressor()

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
predict_knn = model.predict(x_test)

# %%
error = metrics.mean_squared_error(y_test,predict_knn)
print('root mean squared error : ',np.sqrt(error))
r2_Score = metrics.r2_score(y_test,predict_knn)
print("r2 score : ",r2_Score)
# Out:
# root mean squared error :  377.25421311752007
# r2 score :  0.39565663456419564

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.5920013924623675

# %%
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
# Out:
# new test positives on ['03/09/2020']
# actual :     1530
# predicted :  1944

# %%
print('prediction by Linearregression')
test_predicted = model.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')
print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by Decision tree regressor')
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
# Out:
# prediction by Linearregression
# new test positives on ['03/09/2020']
# actual :     1530
# predicted :  2037
# --------------------------------------------------------
# prediction by KNNregressor
# new test positives on ['03/09/2020']
# actual :     1530
# predicted :  1944
# --------------------------------------------------------
# prediction by Decision tree regressor
# new test positives on ['03/09/2020']
# actual :     [1553]
# predicted :  1553

# %% [markdown]
# # Trying with xgboost

# %%
import xgboost as xgb

# %%
model_xgb = xgb.XGBRFRegressor()

# %%
model_xgb.fit(x_train,y_train)
# Out:
# [12:12:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRFRegressor(base_score=0.5, colsample_bylevel=1, colsample_bynode=0.8,
#                colsample_bytree=1, gamma=0, learning_rate=1, max_delta_step=0,
#                max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#                n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#                reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#                silent=None, subsample=0.8, verbosity=1)

# %%
predict_xgb = model_xgb.predict(x_test)

# %%
predict_xgb
# Out:
# array([1568.5846, 1582.8184, 1582.8184, 1582.8184, 1574.8357, 1582.8184,
#        1568.5846, 1582.8184, 1582.8184, 1560.6022], dtype=float32)

# %%
y_test
# Out:
#     New_Positive
# 27          1530
# 15          2333
# 23          2406
# 17          1983
# 8           1212
# 9           1564
# 29          1547
# 24          2543
# 12          1530
# 0           1083

# %%
error = metrics.mean_squared_error(y_test,predict_xgb)
print('mean squared error : ',error)
r2_Score = metrics.r2_score(y_test,predict_xgb)
print("r2 score : ",r2_Score)
# Out:
# mean squared error :  268734.6787183985
# r2 score :  -0.1411409092271334

# %%
#current best 
print('prediction by Linearregression')
test_predicted = model.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')
print('prediction by KNNregressor')
test_predicted = model_knn.predict(np.array(test).reshape(1,-1))

actual = 1530
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted))
print('--------------------------------------------------------')

print('prediction by Decision tree regressor')
test_predicted_tree = model_tree.predict(np.array(test).reshape(1,-1))
actual = test_report.iloc[:,5].tail(1).values
print('new test positives on {0}'.format(np.array(test_report['Date'].tail(1))))
print('actual :    ',actual,'\npredicted : ',int(test_predicted_tree))
# Out:
# prediction by Linearregression
# new test positives on ['03/09/2020']
# actual :     1530
# predicted :  2037
# --------------------------------------------------------
# prediction by KNNregressor
# new test positives on ['03/09/2020']
# actual :     1530
# predicted :  1944
# --------------------------------------------------------
# prediction by Decision tree regressor
# new test positives on ['03/09/2020']
# actual :     [1553]
# predicted :  1553

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1,len(x_train.columns.values),sharey=True,constrained_layout=True,figsize=(30,15))

for i,e in enumerate(x_train.columns):
  model.fit(x_train[e].values[:,np.newaxis], y_train.values)
  axes[i].set_title("Best fit line")
  axes[i].set_xlabel(str(e))
  axes[i].set_ylabel('new positive')
  axes[i].scatter(x_train[e].values[:,np.newaxis], y_train,color='g')
  axes[i].plot(x_train[e].values[:,np.newaxis],model.predict(x_train[e].values[:,np.newaxis]),color='k')

# %%
total_snt = int(test_report['Total_Sent'].tail(1).values)
total_snt
# Out:
# 1755568

# %%
#calculating total processed
Proceed_In_24_Hr = test_report['Proceed_In_24_Hr'].values

# %%
total_processed = 0
for i in Proceed_In_24_Hr:
    total_processed = total_processed + i
unprocessed = total_snt-total_processed
total_postive = int(test_report['Total_Positive'].tail(1).values)
total_negative = total_processed - total_postive
print('total processed until {0} :'.format(test_report['Date'].tail(1).values),total_processed,'\ntotal_unprocessed until {0} :'.format(test_report['Date'].tail(1).values),unprocessed,'\ntotal_positive until {0} :'.format(test_report['Date'].tail(1).values),total_postive,'\ntotal_negtive until {0} :'.format(test_report['Date'].tail(1).values),total_negative)
# Out:
# total processed until ['03/09/2020'] : 912334
# total_unprocessed until ['03/09/2020'] : 843234
# total_positive until ['03/09/2020'] : 79625
# total_negtive until ['03/09/2020'] : 832709

# %%
#calculating the percentages :
total = unprocessed + total_postive + total_negative
unprocessed_perc = (unprocessed/total)*100
positive_perc = (total_postive/total)*100
negtive_per = (total_negative/total)*100
perc = [unprocessed_perc,positive_perc,negtive_per]
perc
# Out:
# [48.031975975866494, 4.535569114953109, 47.432454909180386]

# %%
fig_pie , ax_pie = plt.subplots(figsize=(20,15))

#setting the theme
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['axes.labelcolor'] = '#909090'
plt.rcParams['font.size'] = 24

#setting label names and percentages
ax_pie.set_title('\nVisualizing test reports processed v/s unprocessed\n\n',fontsize='xx-large')
labels = ['\n\n\n\n\n    Unprocessed','Processed +ve','Processed -ve']
explode=(0.05,0,0)
ax_pie.pie(perc,explode=explode,labels=labels, autopct='%1.0f%%', 
       shadow=False,colors = ['#5ADAE0','#367DB5','#1410B0'], startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax_pie.axis('equal')
ax_pie.legend(frameon=False, bbox_to_anchor=(1.5,0.8))
fig_pie.savefig('reports/processed_unprocessed.png')

# %%
total_processed - (total_negative+ total_postive)
# Out:
# 0

# %%
total_postive = int(test_report['Total_Positive'].tail(1).values)
total_negative = total_processed - total_postive
print(total_postive,total_negative)
perc_processed = [ (total_postive/total_processed)*100 , (total_negative/total_processed)*100]
perc_processed
# Out:
# 79625 832709
# [8.727615105871314, 91.27238489412869]

# %%
fig_pie2 , ax_pie = plt.subplots(figsize=(20,15))

#setting the theme
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['axes.labelcolor'] = '#909090'
plt.rcParams['font.size'] = 24

#setting label names and percentages
ax_pie.set_title('\nVisualizing test reports positive v/s negtive\n\n',fontsize='xx-large')
labels = ['Processed +ve','Processed -ve']
explode=(0.1,0)
ax_pie.pie(perc_processed,explode=explode,labels=labels, autopct='%1.0f%%', 
       shadow=False,colors = ['red','#367DB5'], startangle=0,   
       pctdistance=1.2,labeldistance=1.4)
ax_pie.axis('equal')
ax_pie.legend(frameon=False, bbox_to_anchor=(1.5,0.8),loc='lower right',fontsize='xx-large')
fig_pie2.savefig('reports/positive_negtive.png')
