# %%
dist = ['TVM','EKM','KKD','MPM','KLM','TSR','ALP','KNR','KTM','PKD','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 25-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 30171
# enter confirmed cases in  EKM : 14127
# enter confirmed cases in  KKD : 14482
# enter confirmed cases in  MPM : 18380
# enter confirmed cases in  KLM : 10988
# enter confirmed cases in  TSR : 10791
# enter confirmed cases in  ALP : 11919
# enter confirmed cases in  KNR : 9461
# enter confirmed cases in  KTM : 8911
# enter confirmed cases in  PKD : 9445
# enter confirmed cases in  KGD : 9413
# enter confirmed cases in  PTA : 6658
# enter confirmed cases in  IDK : 3232
# enter confirmed cases in  WYD : 2955
# enter recoverd cases in  TVM : 21192
# enter recoverd cases in  EKM : 9247
# enter recoverd cases in  KKD : 9688
# enter recoverd cases in  MPM : 14176
# enter recoverd cases in  KLM : 6972
# enter recoverd cases in  TSR : 6917
# enter recoverd cases in  ALP : 8114
# enter recoverd cases in  KNR : 6065
# enter recoverd cases in  KTM : 5724
# enter recoverd cases in  PKD : 6560
# enter recoverd cases in  KGD : 7074
# enter recoverd cases in  PTA : 4998
# enter recoverd cases in  IDK : 2358
# enter recoverd cases in  WYD : 2246
# enter death cases in TVM : 206
# enter death cases in EKM : 56
# enter death cases in KKD : 61
# enter death cases in MPM : 61
# enter death cases in KLM : 61
# enter death cases in TSR : 47
# enter death cases in ALP : 43
# enter death cases in KNR : 30
# enter death cases in KTM : 40
# enter death cases in PKD : 12
# enter death cases in KGD : 26
# enter death cases in PTA : 41
# enter death cases in IDK : 4
# enter death cases in WYD : 3
# enter active cases in  TVM  : 8740
# enter active cases in  EKM  : 4816
# enter active cases in  KKD  : 4728
# enter active cases in  MPM  : 4137
# enter active cases in  KLM  : 3966
# enter active cases in  TSR  : 3828
# enter active cases in  ALP  : 3771
# enter active cases in  KNR  : 3353
# enter active cases in  KTM  : 3175
# enter active cases in  PKD  : 2858
# enter active cases in  KGD  : 2295
# enter active cases in  PTA  : 1655
# enter active cases in  IDK  : 869
# enter active cases in  WYD  : 704

# %%
for i in range(14):
    death[i] = input()
# Out:
# 206
# 26
# 61
# 61
# 47
# 43
# 30
# 40
# 12
# 26
# 41
# 4
# 3
# 5

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd Death  Active
# 0       TVM      30171     21192   206    8740
# 1       EKM      14127      9247    26    4816
# 2       KKD      14482      9688    61    4728
# 3       MPM      18380     14176    61    4137
# 4       KLM      10988      6972    47    3966
# 5       TSR      10791      6917    43    3828
# 6       ALP      11919      8114    30    3771
# 7       KNR       9461      6065    40    3353
# 8       KTM       8911      5724    12    3175
# 9       PKD       9445      6560    26    2858
# 10      KGD       9413      7074    41    2295
# 11      PTA       6658      4998     4    1655
# 12      IDK       3232      2358     3     869
# 13      WYD       2955      2246     5     704

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '25-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 160933

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 814
# District : MPM
# confirmed: 784
# District : KKD
# confirmed: 690
# District : EKM
# confirmed: 655
# District : TSR
# confirmed: 607
# District : KLM
# confirmed: 569
# District : ALP
# confirmed: 551
# District : PKD
# confirmed: 419
# District : KNR
# confirmed: 419
# District : KTM
# confirmed: 322
# District : KGD
# confirmed: 268
# District : PTA
# confirmed: 191
# District : IDK
# confirmed: 114
# District : WYD
# confirmed: 74

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'KKD',
#  'EKM',
#  'TSR',
#  'KLM',
#  'ALP',
#  'PKD',
#  'KNR',
#  'KTM',
#  'KGD',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
