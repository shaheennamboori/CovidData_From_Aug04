# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','EKM','KKD','KLM','KTM','ALP','TSR','KGD','KNR','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 13-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 21291
# enter confirmed cases in  MPM : 12735
# enter confirmed cases in  EKM : 9121
# enter confirmed cases in  KKD : 8628
# enter confirmed cases in  KLM : 6919
# enter confirmed cases in  KTM : 6194
# enter confirmed cases in  ALP : 7923
# enter confirmed cases in  TSR : 6773
# enter confirmed cases in  KGD : 7192
# enter confirmed cases in  KNR : 6068
# enter confirmed cases in  PKD : 6308
# enter confirmed cases in  PTA : 4786
# enter confirmed cases in  IDK : 2273
# enter confirmed cases in  WYD : 2067
# enter recoverd cases in  TVM : 15998
# enter recoverd cases in  MPM : 9735
# enter recoverd cases in  EKM : 6111
# enter recoverd cases in  KKD : 6141
# enter recoverd cases in  KLM : 4554
# enter recoverd cases in  KTM : 4014
# enter recoverd cases in  ALP : 5760
# enter recoverd cases in  TSR : 4615
# enter recoverd cases in  KGD : 5044
# enter recoverd cases in  KNR : 3966
# enter recoverd cases in  PKD : 4829
# enter recoverd cases in  PTA : 3600
# enter recoverd cases in  IDK : 1766
# enter recoverd cases in  WYD : 1566
# enter death cases in TVM : 148
# enter death cases in MPM : 35
# enter death cases in EKM : 48
# enter death cases in KKD : 42
# enter death cases in KLM : 28
# enter death cases in KTM : 3
# enter death cases in ALP : 19
# enter death cases in TSR : 26
# enter death cases in KGD : 36
# enter death cases in KNR : 35
# enter death cases in PKD : 8
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 5118
# enter active cases in  MPM  : 2959
# enter active cases in  EKM  : 2954
# enter active cases in  KKD  : 2440
# enter active cases in  KLM  : 2334
# enter active cases in  KTM  : 2177
# enter active cases in  ALP  : 2141
# enter active cases in  TSR  : 2130
# enter active cases in  KGD  : 2109
# enter active cases in  KNR  : 2064
# enter active cases in  PKD  : 1469
# enter active cases in  PTA  : 1181
# enter active cases in  IDK  : 503
# enter active cases in  WYD  : 496

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      21291     15998    148    5118
# 1       MPM      12735      9735     35    2959
# 2       EKM       9121      6111     48    2954
# 3       KKD       8628      6141     42    2440
# 4       KLM       6919      4554     28    2334
# 5       KTM       6194      4014      3    2177
# 6       ALP       7923      5760     19    2141
# 7       TSR       6773      4615     26    2130
# 8       KGD       7192      5044     36    2109
# 9       KNR       6068      3966     35    2064
# 10      PKD       6308      4829      8    1469
# 11      PTA       4786      3600      3    1181
# 12      IDK       2273      1766      3     503
# 13      WYD       2067      1566      5     496

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '13-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 108278

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 412
# District : KKD
# confirmed: 399
# District : MPM
# confirmed: 378
# District : EKM
# confirmed: 326
# District : ALP
# confirmed: 252
# District : KNR
# confirmed: 234
# District : PKD
# confirmed: 233
# District : KLM
# confirmed: 205
# District : KTM
# confirmed: 196
# District : TSR
# confirmed: 182
# District : KGD
# confirmed: 124
# District : PTA
# confirmed: 102
# District : WYD
# confirmed: 56
# District : IDK
# confirmed: 40

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'KKD',
#  'MPM',
#  'EKM',
#  'ALP',
#  'KNR',
#  'PKD',
#  'KLM',
#  'KTM',
#  'TSR',
#  'KGD',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases status on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
