# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','EKM','MPM','KLM','KKD','KGD','KTM','TSR','ALP','KNR','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 12-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 20879
# enter confirmed cases in  EKM : 8795
# enter confirmed cases in  MPM : 12357
# enter confirmed cases in  KLM : 6714
# enter confirmed cases in  KKD : 8229
# enter confirmed cases in  KGD : 7068
# enter confirmed cases in  KTM : 5998
# enter confirmed cases in  TSR : 6591
# enter confirmed cases in  ALP : 7671
# enter confirmed cases in  KNR : 5834
# enter confirmed cases in  PKD : 6075
# enter confirmed cases in  PTA : 4684
# enter confirmed cases in  IDK : 2233
# enter confirmed cases in  WYD : 2011
# enter recoverd cases in  TVM : 15707
# enter recoverd cases in  EKM : 5879
# enter recoverd cases in  MPM : 9533
# enter recoverd cases in  KLM : 4414
# enter recoverd cases in  KKD : 6013
# enter recoverd cases in  KGD : 4866
# enter recoverd cases in  KTM : 3889
# enter recoverd cases in  TSR : 4500
# enter recoverd cases in  ALP : 5714
# enter recoverd cases in  KNR : 3878
# enter recoverd cases in  PKD : 4763
# enter recoverd cases in  PTA : 3409
# enter recoverd cases in  IDK : 1746
# enter recoverd cases in  WYD : 1533
# enter death cases in TVM : 140
# enter death cases in EKM : 44
# enter death cases in MPM : 35
# enter death cases in KLM : 26
# enter death cases in KKD : 42
# enter death cases in KGD : 36
# enter death cases in KTM : 3
# enter death cases in TSR : 25
# enter death cases in ALP : 19
# enter death cases in KNR : 35
# enter death cases in PKD : 9
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 5005
# enter active cases in  EKM  : 2864
# enter active cases in  MPM  : 2783
# enter active cases in  KLM  : 2271
# enter active cases in  KKD  : 2169
# enter active cases in  KGD  : 2163
# enter active cases in  KTM  : 2106
# enter active cases in  TSR  : 2064
# enter active cases in  ALP  : 1935
# enter active cases in  KNR  : 1918
# enter active cases in  PKD  : 1301
# enter active cases in  PTA  : 1270
# enter active cases in  IDK  : 483
# enter active cases in  WYD  : 473

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      20879     15707    140    5005
# 1       EKM       8795      5879     44    2864
# 2       MPM      12357      9533     35    2783
# 3       KLM       6714      4414     26    2271
# 4       KKD       8229      6013     42    2169
# 5       KGD       7068      4866     36    2163
# 6       KTM       5998      3889      3    2106
# 7       TSR       6591      4500     25    2064
# 8       ALP       7671      5714     19    1935
# 9       KNR       5834      3878     35    1918
# 10      PKD       6075      4763      9    1301
# 11      PTA       4684      3409      3    1270
# 12      IDK       2233      1746      3     483
# 13      WYD       2011      1533      5     473

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases on {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '12-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 105139

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 566
# District : MPM
# confirmed: 310
# District : KKD
# confirmed: 286
# District : KLM
# confirmed: 265
# District : KNR
# confirmed: 207
# District : EKM
# confirmed: 188
# District : PKD
# confirmed: 184
# District : TSR
# confirmed: 172
# District : KTM
# confirmed: 166
# District : ALP
# confirmed: 163
# District : KGD
# confirmed: 150
# District : PTA
# confirmed: 88
# District : IDK
# confirmed: 86
# District : WYD
# confirmed: 54

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'KKD',
#  'KLM',
#  'KNR',
#  'EKM',
#  'PKD',
#  'TSR',
#  'KTM',
#  'ALP',
#  'KGD',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
