# %%
dist = ['TVM','EKM','KKD','KLM','MPM','TSR','ALP','KNR','PKD','KTM','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 02-10-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 36433
# enter confirmed cases in  EKM : 20208
# enter confirmed cases in  KKD : 21037
# enter confirmed cases in  KLM : 15528
# enter confirmed cases in  MPM : 24257
# enter confirmed cases in  TSR : 15058
# enter confirmed cases in  ALP : 15670
# enter confirmed cases in  KNR : 12549
# enter confirmed cases in  PKD : 13009
# enter confirmed cases in  KTM : 11489
# enter confirmed cases in  KGD : 11732
# enter confirmed cases in  PTA : 8307
# enter confirmed cases in  IDK : 4058
# enter confirmed cases in  WYD : 3894
# enter recoverd cases in  TVM : 24037
# enter recoverd cases in  EKM : 10967
# enter recoverd cases in  KKD : 12960
# enter recoverd cases in  KLM : 8676
# enter recoverd cases in  MPM : 17875
# enter recoverd cases in  TSR : 8563
# enter recoverd cases in  ALP : 10212
# enter recoverd cases in  KNR : 7300
# enter recoverd cases in  PKD : 7998
# enter recoverd cases in  KTM : 6739
# enter recoverd cases in  KGD : 8176
# enter recoverd cases in  PTA : 6063
# enter recoverd cases in  IDK : 2820
# enter recoverd cases in  WYD : 2758
# enter death cases in TVM : 239
# enter death cases in EKM : 72
# enter death cases in KKD : 70
# enter death cases in KLM : 60
# enter death cases in MPM : 73
# enter death cases in TSR : 55
# enter death cases in ALP : 44
# enter death cases in KNR : 47
# enter death cases in PKD : 38
# enter death cases in KTM : 23
# enter death cases in KGD : 56
# enter death cases in PTA : 6
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 12121
# enter active cases in  EKM  : 9161
# enter active cases in  KKD  : 8001
# enter active cases in  KLM  : 6788
# enter active cases in  MPM  : 6573
# enter active cases in  TSR  : 6437
# enter active cases in  ALP  : 5409
# enter active cases in  KNR  : 5199
# enter active cases in  PKD  : 4972
# enter active cases in  KTM  : 3496
# enter active cases in  KGD  : 2237
# enter active cases in  PTA  : 1233
# enter active cases in  IDK  : 1131
# enter active cases in  WYD  : 1131

# %%
active
# Out:
# [12121,
#  9161,
#  8001,
#  6788,
#  6573,
#  6437,
#  5409,
#  5199,
#  4972,
#  4727,
#  3496,
#  2237,
#  1233,
#  1131]

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      36433     24037    239   12121
# 1       EKM      20208     10967     72    9161
# 2       KKD      21037     12960     70    8001
# 3       KLM      15528      8676     60    6788
# 4       MPM      24257     17875     73    6573
# 5       TSR      15058      8563     55    6437
# 6       ALP      15670     10212     44    5409
# 7       KNR      12549      7300     47    5199
# 8       PKD      13009      7998     38    4972
# 9       KTM      11489      6739     23    4727
# 10      KGD      11732      8176     56    3496
# 11      PTA       8307      6063      6    2237
# 12      IDK       4058      2820      3    1233
# 13      WYD       3894      2758      5    1131

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '02-10-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 213229

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : KKD
# confirmed: 1146
# District : TVM
# confirmed: 1096
# District : EKM
# confirmed: 1042
# District : MPM
# confirmed: 1016
# District : KLM
# confirmed: 892
# District : TSR
# confirmed: 812
# District : PKD
# confirmed: 633
# District : KNR
# confirmed: 625
# District : ALP
# confirmed: 605
# District : KGD
# confirmed: 476
# District : KTM
# confirmed: 432
# District : PTA
# confirmed: 239
# District : IDK
# confirmed: 136
# District : WYD
# confirmed: 108

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['KKD',
#  'TVM',
#  'EKM',
#  'MPM',
#  'KLM',
#  'TSR',
#  'PKD',
#  'KNR',
#  'ALP',
#  'KGD',
#  'KTM',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absolute)


fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct=lambda pct: func(pct, values))
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
