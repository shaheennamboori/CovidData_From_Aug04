# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','EKM','MPM','KGD','TSR','KTM','ALP','KKD','KLM','KNR','PTA','PKD','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 10-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed on  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd on  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death on  {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active on  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed on  TVM : 19819
# enter confirmed on  EKM : 8312
# enter confirmed on  MPM : 11657
# enter confirmed on  KGD : 6816
# enter confirmed on  KTM : 6235
# enter confirmed on  KLM : 5611
# enter confirmed on  ALP : 7308
# enter confirmed on  KKD : 7682
# enter confirmed on  TSR : 6146
# enter confirmed on  KNR : 5371
# enter confirmed on  PTA : 4503
# enter confirmed on  PKD : 5782
# enter confirmed on  IDK : 2119
# enter confirmed on  WYD : 1905
# enter recoverd on  TVM : 15006
# enter recoverd on  EKM : 5583
# enter recoverd on  MPM : 9221
# enter recoverd on  KGD : 4634
# enter recoverd on  KTM : 4260
# enter recoverd on  KLM : 3662
# enter recoverd on  ALP : 5369
# enter recoverd on  KKD : 5732
# enter recoverd on  TSR : 4261
# enter recoverd on  KNR : 3682
# enter recoverd on  PTA : 3320
# enter recoverd on  PKD : 4678
# enter recoverd on  IDK : 1679
# enter recoverd on  WYD : 1487
# enter death on  TVM : 131
# enter death on  EKM : 43
# enter death on  MPM : 33
# enter death on  KGD : 36
# enter death on  KTM : 20
# enter death on  KLM : 3
# enter death on  ALP : 17
# enter death on  KKD : 38
# enter death on  TSR : 26
# enter death on  KNR : 34
# enter death on  PTA : 3
# enter death on  PKD : 4
# enter death on  IDK : 3
# enter death on  WYD : 5
# enter active on  TVM  : 4655
# enter active on  EKM  : 2678
# enter active on  MPM  : 2397
# enter active on  KGD  : 2143
# enter active on  KTM  : 1953
# enter active on  KLM  : 1946
# enter active on  ALP  : 1919
# enter active on  KKD  : 1907
# enter active on  TSR  : 1856
# enter active on  KNR  : 1653
# enter active on  PTA  : 1178
# enter active on  PKD  : 1098
# enter active on  IDK  : 436
# enter active on  WYD  : 413

# %%
active[13] = 276

# %%
confirmed
# Out:
# [18730,
#  7809,
#  11126,
#  6406,
#  5198,
#  5540,
#  6801,
#  7091,
#  5612,
#  4844,
#  4178,
#  5457,
#  1990,
#  1733]

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      19819     15006    131    4655
# 1       EKM       8312      5583     43    2678
# 2       MPM      11657      9221     33    2397
# 3       KGD       6816      4634     36    2143
# 4       TSR       6235      4260     20    1953
# 5       KTM       5611      3662      3    1946
# 6       ALP       7308      5369     17    1919
# 7       KKD       7682      5732     38    1907
# 8       KLM       6146      4261     26    1856
# 9       KNR       5371      3682     34    1653
# 10      PTA       4503      3320      3    1178
# 11      PKD       5782      4678      4    1098
# 12      IDK       2119      1679      3     436
# 13      WYD       1905      1487      5     413

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '10-09-2020'

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 558
# District : MPM
# confirmed: 330
# District : TSR
# confirmed: 300
# District : KNR
# confirmed: 276
# District : ALP
# confirmed: 267
# District : KKD
# confirmed: 261
# District : KLM
# confirmed: 244
# District : EKM
# confirmed: 227
# District : KTM
# confirmed: 217
# District : PKD
# confirmed: 194
# District : KGD
# confirmed: 140
# District : PTA
# confirmed: 135
# District : IDK
# confirmed: 105
# District : WYD
# confirmed: 95

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'TSR',
#  'KNR',
#  'ALP',
#  'KKD',
#  'KLM',
#  'EKM',
#  'KTM',
#  'PKD',
#  'KGD',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
