# %%
dist = ['TVM','EKM','KKD','MPM','KLM','TSR','ALP','KNR','KTM','PKD','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 27-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 32074
# enter confirmed cases in  EKM : 15780
# enter confirmed cases in  KKD : 16122
# enter confirmed cases in  MPM : 20121
# enter confirmed cases in  KLM : 12267
# enter confirmed cases in  TSR : 11958
# enter confirmed cases in  ALP : 12809
# enter confirmed cases in  KNR : 10228
# enter confirmed cases in  KTM : 9726
# enter confirmed cases in  PKD : 10480
# enter confirmed cases in  KGD : 9889
# enter confirmed cases in  PTA : 7250
# enter confirmed cases in  IDK : 3464
# enter confirmed cases in  WYD : 3216
# enter recoverd cases in  TVM : 21999
# enter recoverd cases in  EKM : 9830
# enter recoverd cases in  KKD : 10505
# enter recoverd cases in  MPM : 15061
# enter recoverd cases in  KLM : 7429
# enter recoverd cases in  TSR : 7372
# enter recoverd cases in  ALP : 8755
# enter recoverd cases in  KNR : 6365
# enter recoverd cases in  KTM : 6010
# enter recoverd cases in  PKD : 6989
# enter recoverd cases in  KGD : 7361
# enter recoverd cases in  PTA : 5272
# enter recoverd cases in  IDK : 2516
# enter recoverd cases in  WYD : 2457
# enter death cases in TVM : 214
# enter death cases in EKM : 61
# enter death cases in KKD : 65
# enter death cases in MPM : 64
# enter death cases in KLM : 48
# enter death cases in TSR : 46
# enter death cases in ALP : 35
# enter death cases in KNR : 42
# enter death cases in KTM : 13
# enter death cases in PKD : 28
# enter death cases in KGD : 48
# enter death cases in PTA : 5
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 9828
# enter active cases in  EKM  : 5881
# enter active cases in  KKD  : 5546
# enter active cases in  MPM  : 4990
# enter active cases in  KLM  : 4787
# enter active cases in  TSR  : 4537
# enter active cases in  ALP  : 4015
# enter active cases in  KNR  : 3818
# enter active cases in  KTM  : 3703
# enter active cases in  PKD  : 3462
# enter active cases in  KGD  : 2476
# enter active cases in  PTA  : 1972
# enter active cases in  IDK  : 943
# enter active cases in  WYD  : 754

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      32074     21999    214    9828
# 1       EKM      15780      9830     61    5881
# 2       KKD      16122     10505     65    5546
# 3       MPM      20121     15061     64    4990
# 4       KLM      12267      7429     48    4787
# 5       TSR      11958      7372     46    4537
# 6       ALP      12809      8755     35    4015
# 7       KNR      10228      6365     42    3818
# 8       KTM       9726      6010     13    3703
# 9       PKD      10480      6989     28    3462
# 10      KGD       9889      7361     48    2476
# 11      PTA       7250      5272      5    1972
# 12      IDK       3464      2516      3     943
# 13      WYD       3216      2457      5     754

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '27-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 175384

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : KKD
# confirmed: 956
# District : EKM
# confirmed: 924
# District : MPM
# confirmed: 915
# District : TVM
# confirmed: 853
# District : KLM
# confirmed: 690
# District : TSR
# confirmed: 573
# District : PKD
# confirmed: 488
# District : ALP
# confirmed: 476
# District : KTM
# confirmed: 426
# District : KNR
# confirmed: 332
# District : PTA
# confirmed: 263
# District : KGD
# confirmed: 252
# District : WYD
# confirmed: 172
# District : IDK
# confirmed: 125

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['KKD',
#  'EKM',
#  'MPM',
#  'TVM',
#  'KLM',
#  'TSR',
#  'PKD',
#  'ALP',
#  'KTM',
#  'KNR',
#  'PTA',
#  'KGD',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
