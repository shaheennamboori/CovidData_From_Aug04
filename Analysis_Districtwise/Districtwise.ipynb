# %%
dist = ['TVM','EKM','KKD','MPM','KLM','TSR','ALP','KNR','PKD','KTM','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 01-10-2020

# %%
#confirmed = []
recvrd = []
death = []
activee = [] 
# for i in range(14):
#     c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
#     c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    activee.append(a)
# Out:
# enter recoverd cases in  TVM : 23680
# enter recoverd cases in  EKM : 10755
# enter recoverd cases in  KKD : 12537
# enter recoverd cases in  MPM : 16924
# enter recoverd cases in  KLM : 8381
# enter recoverd cases in  TSR : 8293
# enter recoverd cases in  ALP : 9870
# enter recoverd cases in  KNR : 6997
# enter recoverd cases in  PKD : 7777
# enter recoverd cases in  KTM : 6565
# enter recoverd cases in  KGD : 8018
# enter recoverd cases in  PTA : 5845
# enter recoverd cases in  IDK : 2727
# enter recoverd cases in  WYD : 2683
# enter death cases in TVM : 236
# enter death cases in EKM : 69
# enter death cases in KKD : 70
# enter death cases in MPM : 73
# enter death cases in KLM : 53
# enter death cases in TSR : 55
# enter death cases in ALP : 41
# enter death cases in KNR : 47
# enter death cases in PKD : 38
# enter death cases in KTM : 19
# enter death cases in KGD : 56
# enter death cases in PTA : 6
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 11386
# enter active cases in  EKM  : 8334
# enter active cases in  KKD  : 7278
# enter active cases in  MPM  : 6508
# enter active cases in  KLM  : 6199
# enter active cases in  TSR  : 5895
# enter active cases in  ALP  : 5150
# enter active cases in  KNR  : 4877
# enter active cases in  PKD  : 4560
# enter active cases in  KTM  : 4473
# enter active cases in  KGD  : 3178
# enter active cases in  PTA  : 2216
# enter active cases in  IDK  : 1190
# enter active cases in  WYD  : 1098

# %%
confirmed
# Out:
# [35337,
#  19166,
#  19891,
#  23511,
#  14636,
#  14246,
#  15065,
#  11924,
#  12376,
#  11057,
#  11256,
#  8068,
#  3922,
#  3786]

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = activee

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      35337     23680    236   11386
# 1       EKM      19166     10755     69    8334
# 2       KKD      19891     12537     70    7278
# 3       MPM      23511     16924     73    6508
# 4       KLM      14636      8381     53    6199
# 5       TSR      14246      8293     55    5895
# 6       ALP      15065      9870     41    5150
# 7       KNR      11924      6997     47    4877
# 8       PKD      12376      7777     38    4560
# 9       KTM      11057      6565     19    4473
# 10      KGD      11256      8018     56    3178
# 11      PTA       8068      5845      6    2216
# 12      IDK       3922      2727      3    1190
# 13      WYD       3786      2683      5    1098

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '01-10-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 204241

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : KKD
# confirmed: 1072
# District : MPM
# confirmed: 968
# District : EKM
# confirmed: 934
# District : TVM
# confirmed: 856
# District : ALP
# confirmed: 804
# District : KLM
# confirmed: 633
# District : TSR
# confirmed: 613
# District : PKD
# confirmed: 513
# District : KGD
# confirmed: 471
# District : KNR
# confirmed: 435
# District : KTM
# confirmed: 340
# District : PTA
# confirmed: 223
# District : WYD
# confirmed: 143
# District : IDK
# confirmed: 130

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['KKD',
#  'MPM',
#  'EKM',
#  'TVM',
#  'ALP',
#  'KLM',
#  'TSR',
#  'PKD',
#  'KGD',
#  'KNR',
#  'KTM',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absolute)


fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct=lambda pct: func(pct, values))
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
