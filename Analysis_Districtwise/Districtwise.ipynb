# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','EKM','MPM','KGD','KTM','KLM','ALP','KKD','TSR','KNR','PTA','PKD','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 08-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed on  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd on  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death on  {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active on  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed on  TVM : 18730
# enter confirmed on  EKM : 7809
# enter confirmed on  MPM : 11126
# enter confirmed on  KGD : 6406
# enter confirmed on  KTM : 5198
# enter confirmed on  KLM : 5540
# enter confirmed on  ALP : 6801
# enter confirmed on  KKD : 7091
# enter confirmed on  TSR : 5612
# enter confirmed on  KNR : 4844
# enter confirmed on  PTA : 4178
# enter confirmed on  PKD : 5457
# enter confirmed on  IDK : 1990
# enter confirmed on  WYD : 1733
# enter recoverd on  TVM : 13910
# enter recoverd on  EKM : 5362
# enter recoverd on  MPM : 8952
# enter recoverd on  KGD : 4366
# enter recoverd on  KTM : 3465
# enter recoverd on  KLM : 3835
# enter recoverd on  ALP : 5199
# enter recoverd on  KKD : 5466
# enter recoverd on  TSR : 4032
# enter recoverd on  KNR : 3471
# enter recoverd on  PTA : 3151
# enter recoverd on  PKD : 4558
# enter recoverd on  IDK : 1640
# enter recoverd on  WYD : 1452
# enter death on  TVM : 123
# enter death on  EKM : 42
# enter death on  MPM : 26
# enter death on  KGD : 31
# enter death on  KTM : 3
# enter death on  KLM : 26
# enter death on  ALP : 16
# enter death on  KKD : 38
# enter death on  TSR : 18
# enter death on  KNR : 34
# enter death on  PTA : 3
# enter death on  PKD : 4
# enter death on  IDK : 3
# enter death on  WYD : 5
# enter active on  TVM  : 4670
# enter active on  EKM  : 2397
# enter active on  MPM  : 2142
# enter active on  KGD  : 2006
# enter active on  KTM  : 1730
# enter active on  KLM  : 1676
# enter active on  ALP  : 1583
# enter active on  KKD  : 1560
# enter active on  TSR  : 1337
# enter active on  KNR  : 1022
# enter active on  PTA  : 893
# enter active on  PKD  : 346
# enter active on  IDK  : 276
# enter active on  WYD  : 1582

# %%
active[13] = 276

# %%
confirmed
# Out:
# [18730,
#  7809,
#  11126,
#  6406,
#  5198,
#  5540,
#  6801,
#  7091,
#  5612,
#  4844,
#  4178,
#  5457,
#  1990,
#  1733]

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      18730     13910    123    4670
# 1       EKM       7809      5362     42    2397
# 2       MPM      11126      8952     26    2142
# 3       KGD       6406      4366     31    2006
# 4       KTM       5198      3465      3    1730
# 5       KLM       5540      3835     26    1676
# 6       ALP       6801      5199     16    1583
# 7       KKD       7091      5466     38    1582
# 8       TSR       5612      4032     18    1560
# 9       KNR       4844      3471     34    1337
# 10      PTA       4178      3151      3    1022
# 11      PKD       5457      4558      4     893
# 12      IDK       1990      1640      3     346
# 13      WYD       1733      1452      5     276

# %%
file_path = 'data/covid_case_study/' + date
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases  {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '08-09-2020'

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 562
# District : MPM
# confirmed: 358
# District : EKM
# confirmed: 318
# District : KKD
# confirmed: 246
# District : PKD
# confirmed: 226
# District : ALP
# confirmed: 217
# District : KLM
# confirmed: 209
# District : KGD
# confirmed: 166
# District : PTA
# confirmed: 160
# District : KNR
# confirmed: 158
# District : TSR
# confirmed: 129
# District : IDK
# confirmed: 85
# District : WYD
# confirmed: 24
# District : KTM
# confirmed: 168

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'EKM',
#  'KKD',
#  'PKD',
#  'ALP',
#  'KLM',
#  'KGD',
#  'PTA',
#  'KNR',
#  'TSR',
#  'IDK',
#  'WYD',
#  'KTM']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
fig.savefig('reports/covid_case_study/districtcontrib.png')
