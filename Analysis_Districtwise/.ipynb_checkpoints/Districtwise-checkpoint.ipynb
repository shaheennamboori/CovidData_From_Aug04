# %%
dist = ['TVM','KKD','EKM','MPM','KLM','TSR','ALP','KNR','KTM','PKD','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 24-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 29357
# enter confirmed cases in  KKD : 13792
# enter confirmed cases in  EKM : 13472
# enter confirmed cases in  MPM : 17596
# enter confirmed cases in  KLM : 10419
# enter confirmed cases in  TSR : 10184
# enter confirmed cases in  ALP : 11368
# enter confirmed cases in  KNR : 9042
# enter confirmed cases in  KTM : 8589
# enter confirmed cases in  PKD : 9026
# enter confirmed cases in  KGD : 8589
# enter confirmed cases in  PTA : 6467
# enter confirmed cases in  IDK : 3118
# enter confirmed cases in  WYD : 2881
# enter recoverd cases in  TVM : 20781
# enter recoverd cases in  KKD : 9216
# enter recoverd cases in  EKM : 8922
# enter recoverd cases in  MPM : 13588
# enter recoverd cases in  KLM : 6765
# enter recoverd cases in  TSR : 6665
# enter recoverd cases in  ALP : 7896
# enter recoverd cases in  KNR : 5848
# enter recoverd cases in  KTM : 5531
# enter recoverd cases in  PKD : 6337
# enter recoverd cases in  KGD : 6967
# enter recoverd cases in  PTA : 4878
# enter recoverd cases in  IDK : 2289
# enter recoverd cases in  WYD : 2167
# enter death cases in TVM : 200
# enter death cases in KKD : 60
# enter death cases in EKM : 56
# enter death cases in MPM : 60
# enter death cases in KLM : 45
# enter death cases in TSR : 40
# enter death cases in ALP : 26
# enter death cases in KNR : 40
# enter death cases in KTM : 8
# enter death cases in PKD : 26
# enter death cases in KGD : 41
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 8343
# enter active cases in  KKD  : 4511
# enter active cases in  EKM  : 4486
# enter active cases in  MPM  : 3942
# enter active cases in  KLM  : 3606
# enter active cases in  TSR  : 3476
# enter active cases in  ALP  : 3443
# enter active cases in  KNR  : 3151
# enter active cases in  KTM  : 3050
# enter active cases in  PKD  : 2662
# enter active cases in  KGD  : 2134
# enter active cases in  PTA  : 1585
# enter active cases in  IDK  : 824
# enter active cases in  WYD  : 709

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      29357     20781    200    8343
# 1       KKD      13792      9216     60    4511
# 2       EKM      13472      8922     56    4486
# 3       MPM      17596     13588     60    3942
# 4       KLM      10419      6765     45    3606
# 5       TSR      10184      6665     40    3476
# 6       ALP      11368      7896     26    3443
# 7       KNR       9042      5848     40    3151
# 8       KTM       8589      5531      8    3050
# 9       PKD       9026      6337     26    2662
# 10      KGD       9145      6967     41    2134
# 11      PTA       6467      4878      3    1585
# 12      IDK       3118      2289      3     824
# 13      WYD       2881      2167      5     709

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '24-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 154456

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : KKD
# confirmed: 883
# District : TVM
# confirmed: 875
# District : MPM
# confirmed: 763
# District : EKM
# confirmed: 590
# District : TSR
# confirmed: 474
# District : ALP
# confirmed: 453
# District : KLM
# confirmed: 440
# District : KNR
# confirmed: 406
# District : PKD
# confirmed: 353
# District : KTM
# confirmed: 341
# District : KGD
# confirmed: 300
# District : PTA
# confirmed: 189
# District : IDK
# confirmed: 151
# District : WYD
# confirmed: 106

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['KKD',
#  'TVM',
#  'MPM',
#  'EKM',
#  'TSR',
#  'ALP',
#  'KLM',
#  'KNR',
#  'PKD',
#  'KTM',
#  'KGD',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
