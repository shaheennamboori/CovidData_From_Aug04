# %%
dist = ['TVM','EKM','KKD','MPM','KLM','TSR','KNR','ALP','KTM','PKD','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 29-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 33495
# enter confirmed cases in  EKM : 17176
# enter confirmed cases in  KKD : 17877
# enter confirmed cases in  MPM : 21566
# enter confirmed cases in  KLM : 13191
# enter confirmed cases in  TSR : 12825
# enter confirmed cases in  KNR : 10970
# enter confirmed cases in  ALP : 13582
# enter confirmed cases in  KTM : 10275
# enter confirmed cases in  PKD : 11232
# enter confirmed cases in  KGD : 10464
# enter confirmed cases in  PTA : 7559
# enter confirmed cases in  IDK : 3635
# enter confirmed cases in  WYD : 3429
# enter recoverd cases in  TVM : 22938
# enter recoverd cases in  EKM : 10266
# enter recoverd cases in  KKD : 11615
# enter recoverd cases in  MPM : 16001
# enter recoverd cases in  KLM : 7873
# enter recoverd cases in  TSR : 7848
# enter recoverd cases in  KNR : 6686
# enter recoverd cases in  ALP : 9377
# enter recoverd cases in  KTM : 6289
# enter recoverd cases in  PKD : 7458
# enter recoverd cases in  KGD : 7569
# enter recoverd cases in  PTA : 5559
# enter recoverd cases in  IDK : 2636
# enter recoverd cases in  WYD : 2573
# enter death cases in TVM : 220
# enter death cases in EKM : 61
# enter death cases in KKD : 70
# enter death cases in MPM : 71
# enter death cases in KLM : 51
# enter death cases in TSR : 49
# enter death cases in KNR : 47
# enter death cases in ALP : 37
# enter death cases in KTM : 18
# enter death cases in PKD : 30
# enter death cases in KGD : 52
# enter death cases in PTA : 5
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 10303
# enter active cases in  EKM  : 6841
# enter active cases in  KKD  : 6186
# enter active cases in  MPM  : 5488
# enter active cases in  KLM  : 5264
# enter active cases in  TSR  : 4925
# enter active cases in  KNR  : 4234
# enter active cases in  ALP  : 4164
# enter active cases in  KTM  : 3968
# enter active cases in  PKD  : 3743
# enter active cases in  KGD  : 2839
# enter active cases in  PTA  : 1994
# enter active cases in  IDK  : 994
# enter active cases in  WYD  : 851

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      33495     22938    220   10303
# 1       EKM      17176     10266     61    6841
# 2       KKD      17877     11615     70    6186
# 3       MPM      21566     16001     71    5488
# 4       KLM      13191      7873     51    5264
# 5       TSR      12825      7848     49    4925
# 6       KNR      10970      6686     47    4234
# 7       ALP      13582      9377     37    4164
# 8       KTM      10275      6289     18    3968
# 9       PKD      11232      7458     30    3743
# 10      KGD      10464      7569     52    2839
# 11      PTA       7559      5559      5    1994
# 12      IDK       3635      2636      3     994
# 13      WYD       3429      2573      5     851

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '29-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 187276

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : MPM
# confirmed: 1040
# District : TVM
# confirmed: 935
# District : EKM
# confirmed: 859
# District : KKD
# confirmed: 837
# District : KLM
# confirmed: 583
# District : ALP
# confirmed: 524
# District : TSR
# confirmed: 484
# District : KGD
# confirmed: 453
# District : KNR
# confirmed: 432
# District : PKD
# confirmed: 374
# District : KTM
# confirmed: 336
# District : PTA
# confirmed: 271
# District : WYD
# confirmed: 169
# District : IDK
# confirmed: 57

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['MPM',
#  'TVM',
#  'EKM',
#  'KKD',
#  'KLM',
#  'ALP',
#  'TSR',
#  'KGD',
#  'KNR',
#  'PKD',
#  'KTM',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
