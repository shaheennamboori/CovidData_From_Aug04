# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','KKD','EKM','KLM','ALP','TSR','KNR','KTM','KGD','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 18-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 24700
# enter confirmed cases in  MPM : 14511
# enter confirmed cases in  KKD : 10687
# enter confirmed cases in  EKM : 10665
# enter confirmed cases in  KLM : 9332
# enter confirmed cases in  ALP : 8007
# enter confirmed cases in  TSR : 8168
# enter confirmed cases in  KNR : 7350
# enter confirmed cases in  KTM : 7124
# enter confirmed cases in  KGD : 8003
# enter confirmed cases in  PKD : 7348
# enter confirmed cases in  PTA : 5421
# enter confirmed cases in  IDK : 2640
# enter confirmed cases in  WYD : 2425
# enter recoverd cases in  TVM : 18134
# enter recoverd cases in  MPM : 11035
# enter recoverd cases in  KKD : 7348
# enter recoverd cases in  EKM : 7394
# enter recoverd cases in  KLM : 6654
# enter recoverd cases in  ALP : 5377
# enter recoverd cases in  TSR : 5566
# enter recoverd cases in  KNR : 4774
# enter recoverd cases in  KTM : 4636
# enter recoverd cases in  KGD : 5745
# enter recoverd cases in  PKD : 5391
# enter recoverd cases in  PTA : 4212
# enter recoverd cases in  IDK : 1975
# enter recoverd cases in  WYD : 1844
# enter death cases in TVM : 164
# enter death cases in MPM : 45
# enter death cases in KKD : 47
# enter death cases in EKM : 51
# enter death cases in KLM : 19
# enter death cases in ALP : 32
# enter death cases in TSR : 36
# enter death cases in KNR : 36
# enter death cases in KTM : 3
# enter death cases in KGD : 38
# enter death cases in PKD : 19
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 6372
# enter active cases in  MPM  : 3425
# enter active cases in  KKD  : 3287
# enter active cases in  EKM  : 3212
# enter active cases in  KLM  : 2656
# enter active cases in  ALP  : 2596
# enter active cases in  TSR  : 2563
# enter active cases in  KNR  : 2537
# enter active cases in  KTM  : 2485
# enter active cases in  KGD  : 2217
# enter active cases in  PKD  : 1936
# enter active cases in  PTA  : 1204
# enter active cases in  IDK  : 661
# enter active cases in  WYD  : 576

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      24700     18134    164    6372
# 1       MPM      14511     11035     45    3425
# 2       KKD      10687      7348     47    3287
# 3       EKM      10665      7394     51    3212
# 4       KLM       9332      6654     19    2656
# 5       ALP       8007      5377     32    2596
# 6       TSR       8168      5566     36    2563
# 7       KNR       7350      4774     36    2537
# 8       KTM       7124      4636      3    2485
# 9       KGD       8003      5745     38    2217
# 10      PKD       7348      5391     19    1936
# 11      PTA       5421      4212      3    1204
# 12      IDK       2640      1975      3     661
# 13      WYD       2425      1844      5     576

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '18-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 126381

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 926
# District : KKD
# confirmed: 404
# District : KLM
# confirmed: 355
# District : EKM
# confirmed: 348
# District : KNR
# confirmed: 330
# District : TSR
# confirmed: 326
# District : MPM
# confirmed: 297
# District : ALP
# confirmed: 274
# District : PKD
# confirmed: 268
# District : KTM
# confirmed: 225
# District : KGD
# confirmed: 145
# District : PTA
# confirmed: 101
# District : IDK
# confirmed: 100
# District : WYD
# confirmed: 68

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'KKD',
#  'KLM',
#  'EKM',
#  'KNR',
#  'TSR',
#  'MPM',
#  'ALP',
#  'PKD',
#  'KTM',
#  'KGD',
#  'PTA',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
