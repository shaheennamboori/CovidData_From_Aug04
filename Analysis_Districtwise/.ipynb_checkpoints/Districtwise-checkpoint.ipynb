# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','EKM','KKD','ALP','KLM','TSR','KNR','KTM','KGD','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 19-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 25524
# enter confirmed cases in  MPM : 15045
# enter confirmed cases in  EKM : 11016
# enter confirmed cases in  KKD : 11099
# enter confirmed cases in  ALP : 9680
# enter confirmed cases in  KLM : 8604
# enter confirmed cases in  TSR : 8358
# enter confirmed cases in  KNR : 7572
# enter confirmed cases in  KTM : 7387
# enter confirmed cases in  KGD : 8194
# enter confirmed cases in  PKD : 7697
# enter confirmed cases in  PTA : 5642
# enter confirmed cases in  IDK : 2687
# enter confirmed cases in  WYD : 2520
# enter recoverd cases in  TVM : 18698
# enter recoverd cases in  MPM : 11361
# enter recoverd cases in  EKM : 7583
# enter recoverd cases in  KKD : 7692
# enter recoverd cases in  ALP : 6878
# enter recoverd cases in  KLM : 5809
# enter recoverd cases in  TSR : 5568
# enter recoverd cases in  KNR : 4865
# enter recoverd cases in  KTM : 4755
# enter recoverd cases in  KGD : 5947
# enter recoverd cases in  PKD : 5521
# enter recoverd cases in  PTA : 4366
# enter recoverd cases in  IDK : 2029
# enter recoverd cases in  WYD : 1875
# enter death cases in TVM : 169
# enter death cases in MPM : 45
# enter death cases in EKM : 53
# enter death cases in KKD : 47
# enter death cases in ALP : 19
# enter death cases in KLM : 39
# enter death cases in TSR : 36
# enter death cases in KNR : 36
# enter death cases in KTM : 3
# enter death cases in KGD : 40
# enter death cases in PKD : 21
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 6627
# enter active cases in  MPM  : 3633
# enter active cases in  EKM  : 3372
# enter active cases in  KKD  : 3355
# enter active cases in  ALP  : 2780
# enter active cases in  KLM  : 2753
# enter active cases in  TSR  : 2752
# enter active cases in  KNR  : 2668
# enter active cases in  KTM  : 2629
# enter active cases in  KGD  : 2204
# enter active cases in  PKD  : 2153
# enter active cases in  PTA  : 1271
# enter active cases in  IDK  : 654
# enter active cases in  WYD  : 640

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      25524     18698    169    6627
# 1       MPM      15045     11361     45    3633
# 2       EKM      11016      7583     53    3372
# 3       KKD      11099      7692     47    3355
# 4       ALP       9680      6878     19    2780
# 5       KLM       8604      5809     39    2753
# 6       TSR       8358      5568     36    2752
# 7       KNR       7572      4865     36    2668
# 8       KTM       7387      4755      3    2629
# 9       KGD       8194      5947     40    2204
# 10      PKD       7697      5521     21    2153
# 11      PTA       5642      4366      3    1271
# 12      IDK       2687      2029      3     654
# 13      WYD       2520      1875      5     640

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '19-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 131025

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 824
# District : MPM
# confirmed: 534
# District : KLM
# confirmed: 436
# District : KKD
# confirmed: 412
# District : EKM
# confirmed: 351
# District : TSR
# confirmed: 351
# District : PKD
# confirmed: 349
# District : ALP
# confirmed: 348
# District : KTM
# confirmed: 263
# District : KNR
# confirmed: 222
# District : PTA
# confirmed: 221
# District : KGD
# confirmed: 191
# District : WYD
# confirmed: 95
# District : IDK
# confirmed: 47

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'KLM',
#  'KKD',
#  'EKM',
#  'TSR',
#  'PKD',
#  'ALP',
#  'KTM',
#  'KNR',
#  'PTA',
#  'KGD',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
