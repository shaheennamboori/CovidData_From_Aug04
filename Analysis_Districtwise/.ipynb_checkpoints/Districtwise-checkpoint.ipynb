# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','EKM','KKD','KLM','ALP','KTM','TSR','KNR','KGD','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 16-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 22954
# enter confirmed cases in  MPM : 13863
# enter confirmed cases in  EKM : 9934
# enter confirmed cases in  KKD : 9738
# enter confirmed cases in  KLM : 7595
# enter confirmed cases in  ALP : 8691
# enter confirmed cases in  KTM : 6695
# enter confirmed cases in  TSR : 7385
# enter confirmed cases in  KNR : 6760
# enter confirmed cases in  KGD : 7539
# enter confirmed cases in  PKD : 6839
# enter confirmed cases in  PTA : 5184
# enter confirmed cases in  IDK : 2436
# enter confirmed cases in  WYD : 2250
# enter recoverd cases in  TVM : 17099
# enter recoverd cases in  MPM : 10556
# enter recoverd cases in  EKM : 6816
# enter recoverd cases in  KKD : 6725
# enter recoverd cases in  KLM : 4896
# enter recoverd cases in  ALP : 6312
# enter recoverd cases in  KTM : 4404
# enter recoverd cases in  TSR : 5095
# enter recoverd cases in  KNR : 4508
# enter recoverd cases in  KGD : 5511
# enter recoverd cases in  PKD : 5159
# enter recoverd cases in  PTA : 3982
# enter recoverd cases in  IDK : 1855
# enter recoverd cases in  WYD : 1686
# enter death cases in TVM : 157
# enter death cases in MPM : 41
# enter death cases in EKM : 50
# enter death cases in KKD : 47
# enter death cases in KLM : 32
# enter death cases in ALP : 19
# enter death cases in KTM : 3
# enter death cases in TSR : 29
# enter death cases in KNR : 36
# enter death cases in KGD : 37
# enter death cases in PKD : 18
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 5669
# enter active cases in  MPM  : 3260
# enter active cases in  EKM  : 2961
# enter active cases in  KKD  : 2664
# enter active cases in  KLM  : 2357
# enter active cases in  ALP  : 2288
# enter active cases in  KTM  : 2259
# enter active cases in  TSR  : 2213
# enter active cases in  KNR  : 1988
# enter active cases in  KGD  : 1660
# enter active cases in  PKD  : 1197
# enter active cases in  PTA  : 577
# enter active cases in  IDK  : 559
# enter active cases in  WYD  : 559

# %%
active=[5669,3260,3060,2961,2664,2357,2288,2259,2213,1988,1660,1197,577,559]

# %%
# sample = active
# for i in range(len(active)):
#     if i >=2 :
#         if i == 2:
#             temp = sample[i]
#             sample[i] = 3060
#         if i%2 == 1 :
#             temp1 = sample[i]
#             sample[i] = temp
#         if i%2 == 0 and i!= 2:
#             temp = sample[i]
#             sample[i] = temp1
# active

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      22954     17099    157    5669
# 1       MPM      13863     10556     41    3260
# 2       EKM       9934      6816     50    3060
# 3       KKD       9738      6725     47    2961
# 4       KLM       7595      4896     32    2664
# 5       ALP       8691      6312     19    2357
# 6       KTM       6695      4404      3    2288
# 7       TSR       7385      5095     29    2259
# 8       KNR       6760      4508     36    2213
# 9       KGD       7539      5511     37    1988
# 10      PKD       6839      5159     18    1660
# 11      PTA       5184      3982      3    1197
# 12      IDK       2436      1855      3     577
# 13      WYD       2250      1686      5     559

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '16-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 117863

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 675
# District : KKD
# confirmed: 468
# District : ALP
# confirmed: 323
# District : EKM
# confirmed: 319
# District : KLM
# confirmed: 300
# District : MPM
# confirmed: 298
# District : TSR
# confirmed: 263
# District : KNR
# confirmed: 247
# District : PTA
# confirmed: 236
# District : PKD
# confirmed: 220
# District : KTM
# confirmed: 187
# District : KGD
# confirmed: 119
# District : WYD
# confirmed: 99
# District : IDK
# confirmed: 76

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'KKD',
#  'ALP',
#  'EKM',
#  'KLM',
#  'MPM',
#  'TSR',
#  'KNR',
#  'PTA',
#  'PKD',
#  'KTM',
#  'KGD',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases status on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
