# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','EKM','KKD','KLM','KTM','KNR','TSR','ALP','KGD','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 14-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 21623
# enter confirmed cases in  MPM : 13217
# enter confirmed cases in  EKM : 9376
# enter confirmed cases in  KKD : 9010
# enter confirmed cases in  KLM : 7061
# enter confirmed cases in  KTM : 6316
# enter confirmed cases in  KNR : 6300
# enter confirmed cases in  TSR : 6934
# enter confirmed cases in  ALP : 8030
# enter confirmed cases in  KGD : 7248
# enter confirmed cases in  PKD : 6483
# enter confirmed cases in  PTA : 4802
# enter confirmed cases in  IDK : 2331
# enter confirmed cases in  WYD : 2087
# enter recoverd cases in  TVM : 16413
# enter recoverd cases in  MPM : 9996
# enter recoverd cases in  EKM : 6236
# enter recoverd cases in  KKD : 6264
# enter recoverd cases in  KLM : 4719
# enter recoverd cases in  KTM : 4135
# enter recoverd cases in  KNR : 4101
# enter recoverd cases in  TSR : 4755
# enter recoverd cases in  ALP : 5958
# enter recoverd cases in  KGD : 5174
# enter recoverd cases in  PKD : 4922
# enter recoverd cases in  PTA : 3703
# enter recoverd cases in  IDK : 1791
# enter recoverd cases in  WYD : 1642
# enter death cases in TVM : 151
# enter death cases in MPM : 38
# enter death cases in EKM : 49
# enter death cases in KKD : 43
# enter death cases in KLM : 31
# enter death cases in KTM : 3
# enter death cases in KNR : 35
# enter death cases in TSR : 26
# enter death cases in ALP : 19
# enter death cases in KGD : 37
# enter death cases in PKD : 11
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 5031
# enter active cases in  MPM  : 3177
# enter active cases in  EKM  : 3083
# enter active cases in  KKD  : 2698
# enter active cases in  KLM  : 2308
# enter active cases in  KTM  : 2178
# enter active cases in  KNR  : 2161
# enter active cases in  TSR  : 2151
# enter active cases in  ALP  : 2050
# enter active cases in  KGD  : 2034
# enter active cases in  PKD  : 1548
# enter active cases in  PTA  : 1094
# enter active cases in  IDK  : 536
# enter active cases in  WYD  : 440

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      21623     16413    151    5031
# 1       MPM      13217      9996     38    3177
# 2       EKM       9376      6236     49    3083
# 3       KKD       9010      6264     43    2698
# 4       KLM       7061      4719     31    2308
# 5       KTM       6316      4135      3    2178
# 6       KNR       6300      4101     35    2161
# 7       TSR       6934      4755     26    2151
# 8       ALP       8030      5958     19    2050
# 9       KGD       7248      5174     37    2034
# 10      PKD       6483      4922     11    1548
# 11      PTA       4802      3703      3    1094
# 12      IDK       2331      1791      3     536
# 13      WYD       2087      1642      5     440

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '14-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 110818

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : MPM
# confirmed: 482
# District : KKD
# confirmed: 382
# District : TVM
# confirmed: 332
# District : EKM
# confirmed: 255
# District : KNR
# confirmed: 232
# District : PKD
# confirmed: 175
# District : TSR
# confirmed: 161
# District : KLM
# confirmed: 142
# District : KTM
# confirmed: 122
# District : ALP
# confirmed: 107
# District : IDK
# confirmed: 58
# District : KGD
# confirmed: 56
# District : WYD
# confirmed: 20
# District : PTA
# confirmed: 16

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['MPM',
#  'KKD',
#  'TVM',
#  'EKM',
#  'KNR',
#  'PKD',
#  'TSR',
#  'KLM',
#  'KTM',
#  'ALP',
#  'IDK',
#  'KGD',
#  'WYD',
#  'PTA']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases status on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
