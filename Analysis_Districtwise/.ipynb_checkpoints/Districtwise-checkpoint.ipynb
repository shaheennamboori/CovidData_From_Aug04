# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','KKD','EKM','KLM','ALP','TSR','KNR','KTM','KGD','PKD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 17-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 23774
# enter confirmed cases in  MPM : 14214
# enter confirmed cases in  KKD : 10283
# enter confirmed cases in  EKM : 10317
# enter confirmed cases in  KLM : 7813
# enter confirmed cases in  ALP : 9058
# enter confirmed cases in  TSR : 7681
# enter confirmed cases in  KNR : 7020
# enter confirmed cases in  KTM : 6899
# enter confirmed cases in  KGD : 7858
# enter confirmed cases in  PKD : 7080
# enter confirmed cases in  PTA : 5320
# enter confirmed cases in  IDK : 2540
# enter confirmed cases in  WYD : 2357
# enter recoverd cases in  TVM : 17646
# enter recoverd cases in  MPM : 10770
# enter recoverd cases in  KKD : 7000
# enter recoverd cases in  EKM : 7173
# enter recoverd cases in  KLM : 5221
# enter recoverd cases in  ALP : 6508
# enter recoverd cases in  TSR : 5235
# enter recoverd cases in  KNR : 4605
# enter recoverd cases in  KTM : 4524
# enter recoverd cases in  KGD : 5635
# enter recoverd cases in  PKD : 5273
# enter recoverd cases in  PTA : 4084
# enter recoverd cases in  IDK : 1902
# enter recoverd cases in  WYD : 1765
# enter death cases in TVM : 160
# enter death cases in MPM : 42
# enter death cases in KKD : 47
# enter death cases in EKM : 50
# enter death cases in KLM : 35
# enter death cases in ALP : 19
# enter death cases in TSR : 31
# enter death cases in KNR : 36
# enter death cases in KTM : 3
# enter death cases in KGD : 37
# enter death cases in PKD : 18
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 5939
# enter active cases in  MPM  : 3396
# enter active cases in  KKD  : 3231
# enter active cases in  EKM  : 3086
# enter active cases in  KLM  : 2554
# enter active cases in  ALP  : 2528
# enter active cases in  TSR  : 2413
# enter active cases in  KNR  : 2376
# enter active cases in  KTM  : 2372
# enter active cases in  KGD  : 2183
# enter active cases in  PKD  : 1787
# enter active cases in  PTA  : 1231
# enter active cases in  IDK  : 634
# enter active cases in  WYD  : 587

# %%
# active=[5669,3260,3060,2961,2664,2357,2288,2259,2213,1988,1660,1197,577,559]

# %%
# sample = active
# for i in range(len(active)):
#     if i >=2 :
#         if i == 2:
#             temp = sample[i]
#             sample[i] = 3060
#         if i%2 == 1 :
#             temp1 = sample[i]
#             sample[i] = temp
#         if i%2 == 0 and i!= 2:
#             temp = sample[i]
#             sample[i] = temp1
# active

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      23774     17646    160    5939
# 1       MPM      14214     10770     42    3396
# 2       KKD      10283      7000     47    3231
# 3       EKM      10317      7173     50    3086
# 4       KLM       7813      5221     35    2554
# 5       ALP       9058      6508     19    2528
# 6       TSR       7681      5235     31    2413
# 7       KNR       7020      4605     36    2376
# 8       KTM       6899      4524      3    2372
# 9       KGD       7858      5635     37    2183
# 10      PKD       7080      5273     18    1787
# 11      PTA       5320      4084      3    1231
# 12      IDK       2540      1902      3     634
# 13      WYD       2357      1765      5     587

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '17-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 122214

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 820
# District : KKD
# confirmed: 545
# District : EKM
# confirmed: 383
# District : ALP
# confirmed: 367
# District : MPM
# confirmed: 351
# District : KGD
# confirmed: 319
# District : TSR
# confirmed: 296
# District : KNR
# confirmed: 260
# District : PKD
# confirmed: 241
# District : KLM
# confirmed: 218
# District : KTM
# confirmed: 204
# District : PTA
# confirmed: 136
# District : WYD
# confirmed: 107
# District : IDK
# confirmed: 104

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'KKD',
#  'EKM',
#  'ALP',
#  'MPM',
#  'KGD',
#  'TSR',
#  'KNR',
#  'PKD',
#  'KLM',
#  'KTM',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
