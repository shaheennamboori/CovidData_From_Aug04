# %%
dist = ['TVM','EKM','KKD','KLM','TSR','MPM','PKD','KNR','ALP','KTM','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 07-10-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 41472
# enter confirmed cases in  EKM : 24828
# enter confirmed cases in  KKD : 26095
# enter confirmed cases in  KLM : 19083
# enter confirmed cases in  TSR : 18759
# enter confirmed cases in  MPM : 29102
# enter confirmed cases in  PKD : 15452
# enter confirmed cases in  KNR : 15013
# enter confirmed cases in  ALP : 18142
# enter confirmed cases in  KTM : 13576
# enter confirmed cases in  KGD : 13322
# enter confirmed cases in  PTA : 9666
# enter confirmed cases in  IDK : 4507
# enter confirmed cases in  WYD : 4388
# enter recoverd cases in  TVM : 28403
# enter recoverd cases in  EKM : 12732
# enter recoverd cases in  KKD : 15364
# enter recoverd cases in  KLM : 10474
# enter recoverd cases in  TSR : 10228
# enter recoverd cases in  MPM : 21272
# enter recoverd cases in  PKD : 9341
# enter recoverd cases in  KNR : 9182
# enter recoverd cases in  ALP : 12388
# enter recoverd cases in  KTM : 8473
# enter recoverd cases in  KGD : 9038
# enter recoverd cases in  PTA : 6865
# enter recoverd cases in  IDK : 3251
# enter recoverd cases in  WYD : 3242
# enter death cases in TVM : 280
# enter death cases in EKM : 79
# enter death cases in KKD : 76
# enter death cases in KLM : 68
# enter death cases in TSR : 59
# enter death cases in MPM : 90
# enter death cases in PKD : 39
# enter death cases in KNR : 59
# enter death cases in ALP : 54
# enter death cases in KTM : 28
# enter death cases in KGD : 58
# enter death cases in PTA : 6
# enter death cases in IDK : 5
# enter death cases in WYD : 5
# enter active cases in  TVM  : 12752
# enter active cases in  EKM  : 12009
# enter active cases in  KKD  : 10649
# enter active cases in  KLM  : 8537
# enter active cases in  TSR  : 8468
# enter active cases in  MPM  : 7733
# enter active cases in  PKD  : 6071
# enter active cases in  KNR  : 5769
# enter active cases in  ALP  : 5695
# enter active cases in  KTM  : 5075
# enter active cases in  KGD  : 4222
# enter active cases in  PTA  : 2794
# enter active cases in  IDK  : 1249
# enter active cases in  WYD  : 1141

# %%
active
# Out:
# [12752,
#  12009,
#  10649,
#  8537,
#  8468,
#  7733,
#  6071,
#  5769,
#  5695,
#  5075,
#  4222,
#  2794,
#  1249,
#  1141]

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      41472     28403    280   12752
# 1       EKM      24828     12732     79   12009
# 2       KKD      26095     15364     76   10649
# 3       KLM      19083     10474     68    8537
# 4       TSR      18759     10228     59    8468
# 5       MPM      29102     21272     90    7733
# 6       PKD      15452      9341     39    6071
# 7       KNR      15013      9182     59    5769
# 8       ALP      18142     12388     54    5695
# 9       KTM      13576      8473     28    5075
# 10      KGD      13322      9038     58    4222
# 11      PTA       9666      6865      6    2794
# 12      IDK       4507      3251      5    1249
# 13      WYD       4388      3242      5    1141

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '07-10-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 253405

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : KKD
# confirmed: 1576
# District : MPM
# confirmed: 1350
# District : EKM
# confirmed: 1201
# District : TVM
# confirmed: 1182
# District : TSR
# confirmed: 948
# District : KLM
# confirmed: 852
# District : ALP
# confirmed: 672
# District : PKD
# confirmed: 650
# District : KNR
# confirmed: 602
# District : KTM
# confirmed: 490
# District : KGD
# confirmed: 432
# District : PTA
# confirmed: 393
# District : WYD
# confirmed: 138
# District : IDK
# confirmed: 120

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['KKD',
#  'MPM',
#  'EKM',
#  'TVM',
#  'TSR',
#  'KLM',
#  'ALP',
#  'PKD',
#  'KNR',
#  'KTM',
#  'KGD',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d})".format(pct, absolute)


fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct=lambda pct: func(pct, values))
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
