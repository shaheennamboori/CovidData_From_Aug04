# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','EKM','KKD','MPM','KNR','TSR','KLM','KTM','ALP','PKD','KGD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 21-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 26949
# enter confirmed cases in  EKM : 11852
# enter confirmed cases in  KKD : 12011
# enter confirmed cases in  MPM : 15877
# enter confirmed cases in  KNR : 8128
# enter confirmed cases in  TSR : 8863
# enter confirmed cases in  KLM : 9129
# enter confirmed cases in  KTM : 7817
# enter confirmed cases in  ALP : 10011
# enter confirmed cases in  PKD : 8153
# enter confirmed cases in  KGD : 8512
# enter confirmed cases in  PTA : 5848
# enter confirmed cases in  IDK : 2846
# enter confirmed cases in  WYD : 2635
# enter recoverd cases in  TVM : 19695
# enter recoverd cases in  EKM : 8170
# enter recoverd cases in  KKD : 8351
# enter recoverd cases in  MPM : 12235
# enter recoverd cases in  KNR : 5061
# enter recoverd cases in  TSR : 5918
# enter recoverd cases in  KLM : 6203
# enter recoverd cases in  KTM : 5012
# enter recoverd cases in  ALP : 7315
# enter recoverd cases in  PKD : 5838
# enter recoverd cases in  KGD : 6286
# enter recoverd cases in  PTA : 4535
# enter recoverd cases in  IDK : 2131
# enter recoverd cases in  WYD : 1974
# enter death cases in TVM : 175
# enter death cases in EKM : 54
# enter death cases in KKD : 47
# enter death cases in MPM : 56
# enter death cases in KNR : 39
# enter death cases in TSR : 38
# enter death cases in KLM : 40
# enter death cases in KTM : 8
# enter death cases in ALP : 19
# enter death cases in PKD : 25
# enter death cases in KGD : 41
# enter death cases in PTA : 3
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 7047
# enter active cases in  EKM  : 3621
# enter active cases in  KKD  : 3608
# enter active cases in  MPM  : 3580
# enter active cases in  KNR  : 3025
# enter active cases in  TSR  : 2905
# enter active cases in  KLM  : 2883
# enter active cases in  KTM  : 2797
# enter active cases in  ALP  : 2675
# enter active cases in  PKD  : 2289
# enter active cases in  KGD  : 2182
# enter active cases in  PTA  : 1309
# enter active cases in  IDK  : 711
# enter active cases in  WYD  : 656

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      26949     19695    175    7047
# 1       EKM      11852      8170     54    3621
# 2       KKD      12011      8351     47    3608
# 3       MPM      15877     12235     56    3580
# 4       KNR       8128      5061     39    3025
# 5       TSR       8863      5918     38    2905
# 6       KLM       9129      6203     40    2883
# 7       KTM       7817      5012      8    2797
# 8       ALP      10011      7315     19    2675
# 9       PKD       8153      5838     25    2289
# 10      KGD       8512      6286     41    2182
# 11      PTA       5848      4535      3    1309
# 12      IDK       2846      2131      3     711
# 13      WYD       2635      1974      5     656

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '21-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 138631

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 533
# District : KKD
# confirmed: 376
# District : MPM
# confirmed: 349
# District : KNR
# confirmed: 314
# District : EKM
# confirmed: 299
# District : KLM
# confirmed: 195
# District : TSR
# confirmed: 183
# District : PKD
# confirmed: 167
# District : KTM
# confirmed: 156
# District : ALP
# confirmed: 112
# District : KGD
# confirmed: 110
# District : IDK
# confirmed: 82
# District : WYD
# confirmed: 18
# District : PTA
# confirmed: 16

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'KKD',
#  'MPM',
#  'KNR',
#  'EKM',
#  'KLM',
#  'TSR',
#  'PKD',
#  'KTM',
#  'ALP',
#  'KGD',
#  'IDK',
#  'WYD',
#  'PTA']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
