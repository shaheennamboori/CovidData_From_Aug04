# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dist = ['TVM','MPM','KKD','EKM','KLM','TSR','ALP','KTM','KNR','PKD','KGD','PTA','IDK','WYD']

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 20-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 26416
# enter confirmed cases in  MPM : 15528
# enter confirmed cases in  KKD : 11635
# enter confirmed cases in  EKM : 11553
# enter confirmed cases in  KLM : 8934
# enter confirmed cases in  TSR : 8680
# enter confirmed cases in  ALP : 9899
# enter confirmed cases in  KTM : 7661
# enter confirmed cases in  KNR : 7814
# enter confirmed cases in  PKD : 7986
# enter confirmed cases in  KGD : 8402
# enter confirmed cases in  PTA : 5832
# enter confirmed cases in  IDK : 2617
# enter confirmed cases in  WYD : 2764
# enter recoverd cases in  TVM : 19176
# enter recoverd cases in  MPM : 11749
# enter recoverd cases in  KKD : 7932
# enter recoverd cases in  EKM : 7872
# enter recoverd cases in  KLM : 5960
# enter recoverd cases in  TSR : 5778
# enter recoverd cases in  ALP : 7080
# enter recoverd cases in  KTM : 4876
# enter recoverd cases in  KNR : 5022
# enter recoverd cases in  PKD : 5666
# enter recoverd cases in  KGD : 6110
# enter recoverd cases in  PTA : 4455
# enter recoverd cases in  IDK : 1928
# enter recoverd cases in  WYD : 2094
# enter death cases in TVM : 171
# enter death cases in MPM : 48
# enter death cases in KKD : 47
# enter death cases in EKM : 54
# enter death cases in KLM : 40
# enter death cases in TSR : 38
# enter death cases in ALP : 19
# enter death cases in KTM : 8
# enter death cases in KNR : 36
# enter death cases in PKD : 22
# enter death cases in KGD : 41
# enter death cases in PTA : 3
# enter death cases in IDK : 5
# enter death cases in WYD : 3
# enter active cases in  TVM  : 7037
# enter active cases in  MPM  : 3725
# enter active cases in  KKD  : 3651
# enter active cases in  EKM  : 3619
# enter active cases in  KLM  : 2931
# enter active cases in  TSR  : 2862
# enter active cases in  ALP  : 2797
# enter active cases in  KTM  : 2777
# enter active cases in  KNR  : 2753
# enter active cases in  PKD  : 2296
# enter active cases in  KGD  : 2248
# enter active cases in  PTA  : 1372
# enter active cases in  IDK  : 684
# enter active cases in  WYD  : 666

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      26416     19176    171    7037
# 1       MPM      15528     11749     48    3725
# 2       KKD      11635      7932     47    3651
# 3       EKM      11553      7872     54    3619
# 4       KLM       8934      5960     40    2931
# 5       TSR       8680      5778     38    2862
# 6       ALP       9899      7080     19    2797
# 7       KTM       7661      4876      8    2777
# 8       KNR       7814      5022     36    2753
# 9       PKD       7986      5666     22    2296
# 10      KGD       8402      6110     41    2248
# 11      PTA       5832      4455      3    1372
# 12      IDK       2617      1928      5     684
# 13      WYD       2764      2094      3     666

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '20-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 135721

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 892
# District : EKM
# confirmed: 537
# District : KKD
# confirmed: 536
# District : MPM
# confirmed: 483
# District : KLM
# confirmed: 330
# District : TSR
# confirmed: 322
# District : PKD
# confirmed: 289
# District : KTM
# confirmed: 274
# District : KNR
# confirmed: 242
# District : ALP
# confirmed: 219
# District : KGD
# confirmed: 208
# District : PTA
# confirmed: 190
# District : WYD
# confirmed: 97
# District : IDK
# confirmed: 77

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'EKM',
#  'KKD',
#  'MPM',
#  'KLM',
#  'TSR',
#  'PKD',
#  'KTM',
#  'KNR',
#  'ALP',
#  'KGD',
#  'PTA',
#  'WYD',
#  'IDK']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
