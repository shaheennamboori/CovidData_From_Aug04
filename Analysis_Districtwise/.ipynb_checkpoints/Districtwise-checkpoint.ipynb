# %%
dist = ['TVM','EKM','KKD','MPM','KLM','TSR','ALP','KNR','KTM','PKD','KGD','PTA','IDK','WYD']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
date = (input('enter date dd-mm-yy : '))
# Out:
# enter date dd-mm-yy : 26-09-2020

# %%
confirmed = []
recvrd = []
death = []
active = [] 
for i in range(14):
    c = int(input('enter confirmed cases in  {0} : '.format(dist[i])))
    c = confirmed.append(c)              
for i in range(14):
    r= int(input('enter recoverd cases in  {0} : '.format(dist[i])))
    recvrd.append(r)
for i in range(14):
    d = int(input('enter death cases in {0} : '.format(dist[i])))
    death.append(d)
for i in range(14):
    a = int(input('enter active cases in  {0}  : '.format(dist[i])))
    active.append(a)
# Out:
# enter confirmed cases in  TVM : 31221
# enter confirmed cases in  EKM : 14856
# enter confirmed cases in  KKD : 15166
# enter confirmed cases in  MPM : 19206
# enter confirmed cases in  KLM : 11577
# enter confirmed cases in  TSR : 11385
# enter confirmed cases in  ALP : 12333
# enter confirmed cases in  KNR : 9896
# enter confirmed cases in  KTM : 9300
# enter confirmed cases in  PKD : 9992
# enter confirmed cases in  KGD : 9637
# enter confirmed cases in  PTA : 6987
# enter confirmed cases in  IDK : 3339
# enter confirmed cases in  WYD : 3044
# enter recoverd cases in  TVM : 21565
# enter recoverd cases in  EKM : 9493
# enter recoverd cases in  KKD : 10102
# enter recoverd cases in  MPM : 14662
# enter recoverd cases in  KLM : 7160
# enter recoverd cases in  TSR : 7157
# enter recoverd cases in  ALP : 8449
# enter recoverd cases in  KNR : 6212
# enter recoverd cases in  KTM : 5887
# enter recoverd cases in  PKD : 6783
# enter recoverd cases in  KGD : 7151
# enter recoverd cases in  PTA : 5147
# enter recoverd cases in  IDK : 2422
# enter recoverd cases in  WYD : 2340
# enter death cases in TVM : 208
# enter death cases in EKM : 59
# enter death cases in KKD : 61
# enter death cases in MPM : 64
# enter death cases in KLM : 47
# enter death cases in TSR : 45
# enter death cases in ALP : 34
# enter death cases in KNR : 40
# enter death cases in KTM : 12
# enter death cases in PKD : 26
# enter death cases in KGD : 47
# enter death cases in PTA : 5
# enter death cases in IDK : 3
# enter death cases in WYD : 5
# enter active cases in  TVM  : 9415
# enter active cases in  EKM  : 5296
# enter active cases in  KKD  : 4998
# enter active cases in  MPM  : 4474
# enter active cases in  KLM  : 4367
# enter active cases in  TSR  : 4180
# enter active cases in  ALP  : 3846
# enter active cases in  KNR  : 3641
# enter active cases in  KTM  : 3401
# enter active cases in  PKD  : 3182
# enter active cases in  KGD  : 2436
# enter active cases in  PTA  : 1834
# enter active cases in  IDK  : 912
# enter active cases in  WYD  : 699

# %%
# arrays = [dist, confirmed,recvrd,death,active]
# sample = pd.MultiIndex.from_arrays(arrays, names=('District','Confirmed','Recoverd','Death','Active'))
sample_df = pd.DataFrame(columns=['District','Confirmed','Recoverd','Death','Active'])

# %%
sample_df['District'] = dist
sample_df['Confirmed'] = confirmed
sample_df['Recoverd'] = recvrd
sample_df['Death'] = death
sample_df['Active'] = active

# %%
sample_df
# Out:
#    District  Confirmed  Recoverd  Death  Active
# 0       TVM      31221     21565    208    9415
# 1       EKM      14856      9493     59    5296
# 2       KKD      15166     10102     61    4998
# 3       MPM      19206     14662     64    4474
# 4       KLM      11577      7160     47    4367
# 5       TSR      11385      7157     45    4180
# 6       ALP      12333      8449     34    3846
# 7       KNR       9896      6212     40    3641
# 8       KTM       9300      5887     12    3401
# 9       PKD       9992      6783     26    3182
# 10      KGD       9637      7151     47    2436
# 11      PTA       6987      5147      5    1834
# 12      IDK       3339      2422      3     912
# 13      WYD       3044      2340      5     699

# %%
file_path = 'data/covid_case_study/' + date+'.csv'
sample_df.to_csv(file_path)

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Active'],color='darkred')

plt.xticks(rotation = 90)
plt.title('Disrictwise active cases till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/active_cases.png')

# %%
fig,ax= plt.subplots(figsize=(15,8))
#plt.grid(True)
bars = ax.bar(sample_df['District'],sample_df['Death'],color='black')

plt.xticks(rotation = 90)
plt.title('Disrictwise death report till {0}\n'.format(date),fontsize=20,weight='bold')
plt.ylabel('No.of people \n',fontsize='x-large',weight='bold')
plt.xlabel('\n',fontsize='x-large',weight='bold')
for bar in bars:
    ax.text(
        bar.get_x()+bar.get_width() /2,
        bar.get_height(),
        round(bar.get_height()),
        horizontalalignment='center',
        weight = 'bold',
        fontsize=12
    )

    
fig.savefig('reports/covid_case_study/deathrate.png')

# %%
date
# Out:
# '26-09-2020'

# %%
sum = 0
for i in confirmed:
    sum = sum + i
print(sum)
# Out:
# 167939

# %%
confirmed_daily = {}
for i in range(14):
    dis = input('District : ')
    confirmed = int(input('confirmed: '))
    confirmed_daily[dis] = confirmed
# Out:
# District : TVM
# confirmed: 1050
# District : MPM
# confirmed: 826
# District : EKM
# confirmed: 729
# District : KKD
# confirmed: 684
# District : TSR
# confirmed: 594
# District : KLM
# confirmed: 589
# District : PKD
# confirmed: 547
# District : KNR
# confirmed: 435
# District : ALP
# confirmed: 414
# District : KTM
# confirmed: 389
# District : PTA
# confirmed: 329
# District : KGD
# confirmed: 224
# District : IDK
# confirmed: 107
# District : WYD
# confirmed: 89

# %%
s = list(confirmed_daily.keys())
s
# Out:
# ['TVM',
#  'MPM',
#  'EKM',
#  'KKD',
#  'TSR',
#  'KLM',
#  'PKD',
#  'KNR',
#  'ALP',
#  'KTM',
#  'PTA',
#  'KGD',
#  'IDK',
#  'WYD']

# %%
fig , ax = plt.subplots(figsize=(20,14))
color1 = {1:'#FFC154',2:'#EC6B56',3:'#47B39C',4:'#009A4E',5:'#115473',6:'#17719B',7:'#AA5F27',8:'#DEAE24',9:'#276846',10:'#C9252E',11:'#1D181A',12:'#7252AF',13:'#1B7A74',14:'#43B74C'}
color = list(color1.values())
values = list(confirmed_daily.values())
labels = list(confirmed_daily.keys())
ax.pie(values,labels=labels,colors=color,autopct='%.1f%%')
ax.legend(labels,loc='best')
plt.title('Districtwise confirmed cases on {0}'.format(date),fontsize=20,weight='bold')
fig.savefig('reports/covid_case_study/districtcontrib.png')
